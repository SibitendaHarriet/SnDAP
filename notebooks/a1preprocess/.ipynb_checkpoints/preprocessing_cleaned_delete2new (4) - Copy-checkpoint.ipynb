# %%
#!pip install numpy==1.21

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd

import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout, Activation, Input, Bidirectional,SimpleRNN, Embedding, Conv1D, LSTM, MaxPooling1D, GlobalMaxPooling1D, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split


from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_selection import chi2
from IPython.display import display
from sklearn.model_selection import train_test_split



from nltk.stem import PorterStemmer
import re
import nltk
nltk.download('stopwords')
nltk.download('punkt')
from nltk.corpus import stopwords

import matplotlib.pyplot as plt
import seaborn as sns

print(tf.__version__)
# Out:
# 2.12.0
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# # df.to_csv('/content/drive/MyDrive/Colab Notebooks/bertfullbertopics.csv')
# df=pd.read_csv('D:/senego/dataafrica/oldfiles/facebook.csv')
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/facebook.csv')

# %%
df.head(2)
# Out:
#   Unnamed: 0                              time  \
# 0          0                         not found
# 1        114  150319_HONORIS_19201080_LONGFORM
#
#                               links_ID                     username  \
# 0                              nolinks                         LIVE
# 1  /HonorisUni/videos/785448115162801/  Honoris United Universities
#
#                                                title  \
# 0                                          not found
# 1  150319_HONORIS_19201080_LONGFORM\nHonoris Unit...
#
#                                                desc1  \
# 0                                       Create story
# 1  Introducing our 14 inspiring African women ent...
#
#                               desc2  \
# 0                         not found
# 1  150319_HONORIS_19201080_LONGFORM
#
#                                            reactions Unnamed: 8 Unnamed: 9  \
# 0                                       no reactions        NaN        NaN
# 1  Honoris United UniversitiesMar 18, 2019 · 22K ...        NaN        NaN
#
#   Unnamed: 10
# 0         NaN
# 1         NaN

# %%
df=df.astype(str)

# %%
df['Text'] = df[['title','desc1','desc2','reactions','time']].apply(lambda x: ''.join(x), axis=1)
df.head(2)
# Out:
#   Unnamed: 0                              time  \
# 0          0                         not found
# 1        114  150319_HONORIS_19201080_LONGFORM
#
#                               links_ID                     username  \
# 0                              nolinks                         LIVE
# 1  /HonorisUni/videos/785448115162801/  Honoris United Universities
#
#                                                title  \
# 0                                          not found
# 1  150319_HONORIS_19201080_LONGFORM\nHonoris Unit...
#
#                                                desc1  \
# 0                                       Create story
# 1  Introducing our 14 inspiring African women ent...
#
#                               desc2  \
# 0                         not found
# 1  150319_HONORIS_19201080_LONGFORM
#
#                                            reactions Unnamed: 8 Unnamed: 9  \
# 0                                       no reactions        nan        nan
# 1  Honoris United UniversitiesMar 18, 2019 · 22K ...        nan        nan
#
#   Unnamed: 10                                               Text
# 0         nan  not foundCreate storynot foundno reactionsnot ...
# 1         nan  150319_HONORIS_19201080_LONGFORM\nHonoris Unit...

# %%
import re
from dateutil import parser
import pandas as pd

date_reg = r'(\b(?:\d{1,2}/\d{1,2}/\d{4}|[A-Z][a-z]* \d{1,2}(?:,)? \d{4})\b)'

# Function to extract and parse dates
def extract_and_parse_date(text):
    matches = re.findall(date_reg, text)
    for match in matches:
        try:
            parsed_date = parser.parse(match, fuzzy=True)
            return parsed_date
        except ValueError:
            pass
    return None

# Apply the function to the 'Textf' column and create a new 'Date' column
df['Date'] = df['Text'].apply(extract_and_parse_date)

# Display the updated DataFrame
df.head()
# Out:
#   Unnamed: 0                                               time  \
# 0          0                                          not found
# 1        114                   150319_HONORIS_19201080_LONGFORM
# 2        115  International Conference 'Investing in Social ...
# 3        116  What's Trending!!! The Mpu Dance has Taken up ...
# 4        117  THIS VIDEO CHALLENGES YOUR EARS, EYES AND THEI...
#
#                                             links_ID  \
# 0                                            nolinks
# 1                /HonorisUni/videos/785448115162801/
# 2                 /KISMC.SEE/videos/352912361931747/
# 3  /watch/?ref=search&v=574083383066084&external_...
# 4  /watch/?ref=search&v=794583170981978&external_...
#
#                                             username  \
# 0                                               LIVE
# 1                        Honoris United Universities
# 2  Knowledge, Innovation and Strategies Managemen...
# 3                                          Zed Stars
# 4                                      Alif Dawah TV
#
#                                                title  \
# 0                                          not found
# 1  150319_HONORIS_19201080_LONGFORM\nHonoris Unit...
# 2  International Conference 'Investing in Social ...
# 3  What's Trending!!! The Mpu Dance has Taken up ...
# 4  THIS VIDEO CHALLENGES YOUR EARS, EYES AND THEI...
#
#                                                desc1  \
# 0                                       Create story
# 1  Introducing our 14 inspiring African women ent...
# 2  Join us at the international conference 'Inves...
# 3  What's Trending!!! The Mpu Dance has Taken up ...
# 4  THIS VIDEO CHALLENGES YOUR EARS, EYES AND THEI...
#
#                                                desc2  \
# 0                                          not found
# 1                   150319_HONORIS_19201080_LONGFORM
# 2  International Conference 'Investing in Social ...
# 3  What's Trending!!! The Mpu Dance has Taken up ...
# 4  THIS VIDEO CHALLENGES YOUR EARS, EYES AND THEI...
#
#                                            reactions Unnamed: 8 Unnamed: 9  \
# 0                                       no reactions        nan        nan
# 1  Honoris United UniversitiesMar 18, 2019 · 22K ...        nan        nan
# 2  Knowledge, Innovation and Strategies Managemen...        nan        nan
# 3                  Zed StarsFeb 25, 2019 · 619 views        nan        nan
# 4              Alif Dawah TVNov 10, 2019 · 548 views        nan        nan
#
#   Unnamed: 10                                               Text  \
# 0         nan  not foundCreate storynot foundno reactionsnot ...
# 1         nan  150319_HONORIS_19201080_LONGFORM\nHonoris Unit...
# 2         nan  International Conference 'Investing in Social ...
# 3         nan  What's Trending!!! The Mpu Dance has Taken up ...
# 4         nan  THIS VIDEO CHALLENGES YOUR EARS, EYES AND THEI...
#
#                   Date
# 0                 None
# 1  2019-03-18 00:00:00
# 2  2019-06-08 00:00:00
# 3  2019-02-25 00:00:00
# 4  2019-11-10 00:00:00

# %%
df.shape
# Out:
# (4641, 13)

# %%
# Regular expression to extract the views
views_reg = r'(\d+(?:\.\d+)?(?:k)?) views'

# Function to extract views or return 0 if no match
def extract_views(text):
    match = re.search(views_reg, text, re.IGNORECASE)
    if match:
        views_text = match.group(1)
        if 'k' in views_text.lower():
            return int(float(views_text[:-1]) * 1000)
        else:
            return int(views_text.replace(',', ''))
    return 0

# Extract views using the function
df['Views'] = df['Text'].apply(extract_views)

df.head()
# Out:
#   Unnamed: 0                                               time  \
# 0          0                                          not found
# 1        114                   150319_HONORIS_19201080_LONGFORM
# 2        115  International Conference 'Investing in Social ...
# 3        116  What's Trending!!! The Mpu Dance has Taken up ...
# 4        117  THIS VIDEO CHALLENGES YOUR EARS, EYES AND THEI...
#
#                                             links_ID  \
# 0                                            nolinks
# 1                /HonorisUni/videos/785448115162801/
# 2                 /KISMC.SEE/videos/352912361931747/
# 3  /watch/?ref=search&v=574083383066084&external_...
# 4  /watch/?ref=search&v=794583170981978&external_...
#
#                                             username  \
# 0                                               LIVE
# 1                        Honoris United Universities
# 2  Knowledge, Innovation and Strategies Managemen...
# 3                                          Zed Stars
# 4                                      Alif Dawah TV
#
#                                                title  \
# 0                                          not found
# 1  150319_HONORIS_19201080_LONGFORM\nHonoris Unit...
# 2  International Conference 'Investing in Social ...
# 3  What's Trending!!! The Mpu Dance has Taken up ...
# 4  THIS VIDEO CHALLENGES YOUR EARS, EYES AND THEI...
#
#                                                desc1  \
# 0                                       Create story
# 1  Introducing our 14 inspiring African women ent...
# 2  Join us at the international conference 'Inves...
# 3  What's Trending!!! The Mpu Dance has Taken up ...
# 4  THIS VIDEO CHALLENGES YOUR EARS, EYES AND THEI...
#
#                                                desc2  \
# 0                                          not found
# 1                   150319_HONORIS_19201080_LONGFORM
# 2  International Conference 'Investing in Social ...
# 3  What's Trending!!! The Mpu Dance has Taken up ...
# 4  THIS VIDEO CHALLENGES YOUR EARS, EYES AND THEI...
#
#                                            reactions Unnamed: 8 Unnamed: 9  \
# 0                                       no reactions        nan        nan
# 1  Honoris United UniversitiesMar 18, 2019 · 22K ...        nan        nan
# 2  Knowledge, Innovation and Strategies Managemen...        nan        nan
# 3                  Zed StarsFeb 25, 2019 · 619 views        nan        nan
# 4              Alif Dawah TVNov 10, 2019 · 548 views        nan        nan
#
#   Unnamed: 10                                               Text  \
# 0         nan  not foundCreate storynot foundno reactionsnot ...
# 1         nan  150319_HONORIS_19201080_LONGFORM\nHonoris Unit...
# 2         nan  International Conference 'Investing in Social ...
# 3         nan  What's Trending!!! The Mpu Dance has Taken up ...
# 4         nan  THIS VIDEO CHALLENGES YOUR EARS, EYES AND THEI...
#
#                   Date  Views
# 0                 None      0
# 1  2019-03-18 00:00:00  22000
# 2  2019-06-08 00:00:00   1500
# 3  2019-02-25 00:00:00    619
# 4  2019-11-10 00:00:00    548

# %%
# df.to_csv('D:/senego/dataafrica/oldfiles/facebook2new.csv')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'time', 'links_ID', 'username', 'title', 'desc1', 'desc2',
#        'reactions', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Text', 'Date',
#        'Views'],
#       dtype='object')

# %%
df.shape
# Out:
# (4641, 14)

# %%
facebook= df[['username', 'Text','Date', 'Views']]

facebooknew = facebook.dropna(how='all')
facebooknew.head(2)
# Out:
#                       username  \
# 0                         LIVE
# 1  Honoris United Universities
#
#                                                 Text                 Date  \
# 0  not foundCreate storynot foundno reactionsnot ...                 None
# 1  150319_HONORIS_19201080_LONGFORM\nHonoris Unit...  2019-03-18 00:00:00
#
#    Views
# 0      0
# 1  22000

# %%
# facebook.to_csv('D:/senego/dataafrica/oldfiles/facebook2new.csv')
facebook.to_csv('/content/drive/MyDrive/Colab Notebooks/facebook2new.csv')

# %%
facebook["sourcetype"] = "facebook"
facebook.head(4)
# Out:
# <ipython-input-16-f2121b448448>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   facebook["sourcetype"] = "facebook"
#                                             username  \
# 0                                               LIVE
# 1                        Honoris United Universities
# 2  Knowledge, Innovation and Strategies Managemen...
# 3                                          Zed Stars
#
#                                                 Text                 Date  \
# 0  not foundCreate storynot foundno reactionsnot ...                 None
# 1  150319_HONORIS_19201080_LONGFORM\nHonoris Unit...  2019-03-18 00:00:00
# 2  International Conference 'Investing in Social ...  2019-06-08 00:00:00
# 3  What's Trending!!! The Mpu Dance has Taken up ...  2019-02-25 00:00:00
#
#    Views sourcetype
# 0      0   facebook
# 1  22000   facebook
# 2   1500   facebook
# 3    619   facebook

# %%
# Adding a new column "fid" with row numbers ordered by "sourcetype"
# df['fid'] = df.groupby('sourcetype').cumcount() + 1
facebook['fid'] = range(1, len(facebook) + 1)
# Displaying the first 2 rows
facebook.head(2)
# print(result)
# Out:
# <ipython-input-17-cc06a4b446a0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   facebook['fid'] = range(1, len(facebook) + 1)
#                       username  \
# 0                         LIVE
# 1  Honoris United Universities
#
#                                                 Text                 Date  \
# 0  not foundCreate storynot foundno reactionsnot ...                 None
# 1  150319_HONORIS_19201080_LONGFORM\nHonoris Unit...  2019-03-18 00:00:00
#
#    Views sourcetype  fid
# 0      0   facebook    1
# 1  22000   facebook    2

# %%
# newfacebook_df = facebook.dropna()
newfacebook_df = facebook.drop_duplicates('Text')

# %%
newfacebook_df.shape
# newfacebook_df2=facebook.dropna()
# newfacebook_df2.shape
# facebook.shape
# Out:
# (3439, 6)

# %%
# newfacebook_df.to_csv('/content/drive/MyDrive/Colab Notebooks/newfacebook_df2.csv')

# %%
# dfnew2 = df.drop_duplicates('Text_lemma')
# face

# %%
facebook.columns
# Out:
# Index(['username', 'Text', 'Date', 'Views', 'sourcetype', 'fid'], dtype='object')

# %%
newfacebook_df.shape
# Out:
# (3439, 6)

# %%
facebook2 = newfacebook_df[["fid", "Date", "Text","sourcetype","Views"]]
facebook2.head(10)
# Out:
#    fid                 Date  \
# 0    1                 None
# 1    2  2019-03-18 00:00:00
# 2    3  2019-06-08 00:00:00
# 3    4  2019-02-25 00:00:00
# 4    5  2019-11-10 00:00:00
# 5    6  2022-11-16 00:00:00
# 6    7  2019-03-08 00:00:00
# 7    8  2019-04-15 00:00:00
# 8    9  2019-09-08 00:00:00
# 9   10  2019-12-29 00:00:00
#
#                                                 Text sourcetype   Views
# 0  not foundCreate storynot foundno reactionsnot ...   facebook       0
# 1  150319_HONORIS_19201080_LONGFORM\nHonoris Unit...   facebook   22000
# 2  International Conference 'Investing in Social ...   facebook    1500
# 3  What's Trending!!! The Mpu Dance has Taken up ...   facebook     619
# 4  THIS VIDEO CHALLENGES YOUR EARS, EYES AND THEI...   facebook     548
# 5  AFRICA CONTINENTAL FREE TRADE AREA: WHAT IT ME...   facebook     122
# 6  VCW Social Impact: How VCW helped girls in Moz...   facebook      27
# 7  Africa Pay & ID Expo 2019 - Best Of\nOne Afric...   facebook     136
# 8  African Tribes of the Philippines (part 2)\nTr...   facebook  149000
# 9  Climate Entrepreneurship in East Africa with B...   facebook     206

# %%
facebook2.shape
# Out:
# (3439, 5)

# %%
# facebook_df.limit(5)

# %%
newfacebook_df.columns
# Out:
# Index(['username', 'Text', 'Date', 'Views', 'sourcetype', 'fid'], dtype='object')

# %%
facebook2 = newfacebook_df[["fid", "Date", "Text","sourcetype","Views"]]
facebook2.rename(columns={"Text": "textf"}, inplace=True)
facebook2.head(10)
# Out:
# <ipython-input-37-e6448a626e56>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   facebook2.rename(columns={"Text": "textf"}, inplace=True)
#    fid                 Date  \
# 0    1                 None
# 1    2  2019-03-18 00:00:00
# 2    3  2019-06-08 00:00:00
# 3    4  2019-02-25 00:00:00
# 4    5  2019-11-10 00:00:00
# 5    6  2022-11-16 00:00:00
# 6    7  2019-03-08 00:00:00
# 7    8  2019-04-15 00:00:00
# 8    9  2019-09-08 00:00:00
# 9   10  2019-12-29 00:00:00
#
#                                                textf sourcetype   Views
# 0  not foundCreate storynot foundno reactionsnot ...   facebook       0
# 1  150319_HONORIS_19201080_LONGFORM\nHonoris Unit...   facebook   22000
# 2  International Conference 'Investing in Social ...   facebook    1500
# 3  What's Trending!!! The Mpu Dance has Taken up ...   facebook     619
# 4  THIS VIDEO CHALLENGES YOUR EARS, EYES AND THEI...   facebook     548
# 5  AFRICA CONTINENTAL FREE TRADE AREA: WHAT IT ME...   facebook     122
# 6  VCW Social Impact: How VCW helped girls in Moz...   facebook      27
# 7  Africa Pay & ID Expo 2019 - Best Of\nOne Afric...   facebook     136
# 8  African Tribes of the Philippines (part 2)\nTr...   facebook  149000
# 9  Climate Entrepreneurship in East Africa with B...   facebook     206

# %%
facebook2.to_csv('/content/drive/MyDrive/Colab Notebooks/facebook2.csv')
facebook.to_csv('/content/drive/MyDrive/Colab Notebooks/facebook1.csv')

# %%
# # df.to_csv('/content/drive/MyDrive/Colab Notebooks/bertfullbertopics.csv')
# youtube=pd.read_csv('D:/senego/dataafrica/oldfiles/youtube.csv')
youtube=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/youtube.csv')

# %%
youtube=youtube.astype(str)

# %%
youtube['Texty'] = youtube[['title','desc1','desc2','reactions','time']].apply(lambda x: ''.join(x), axis=1)
youtube.head(2)
# Out:
#   Unnamed: 0       time              links_ID         username  \
# 0          0  208 views  /watch?v=NVtfCfwMpYo      CGTN Africa
# 1          1   3K views  /watch?v=s8Tl9XX1wzg  AFP News Agency
#
#                                                title  \
# 0  Hundreds gather to discuss ways of addressing ...
# 1  South Africa's challenges by AFP News Agency 9...
#
#                                                desc1      desc2     reactions  \
# 0                                          not found  not found  no reactions
# 1  Former president Nelson Mandela retired from a...  not found  no reactions
#
#                                                Texty
# 0  Hundreds gather to discuss ways of addressing ...
# 1  South Africa's challenges by AFP News Agency 9...

# %%
from dateutil import parser
from dateutil.relativedelta import relativedelta
import re
from datetime import datetime, timedelta
import pandas as pd

def extract_date(row):
    text = row['Texty']
    try:
        if 'years ago' in text:
            years = int(re.search(r'(\d+)\s*years', text).group(1))
            return datetime.now().date() - relativedelta(years=years)
        elif 'year ago' in text:
            years = 1
            return datetime.now().date() - relativedelta(years=years)
        elif 'months ago' in text:
            months = int(re.search(r'(\d+)\s*months', text).group(1))
            return datetime.now().date() - relativedelta(months=months)
        elif 'month ago' in text:
            months = 1
            return datetime.now().date() - relativedelta(months=months)
        elif 'weeks ago' in text:
            weeks = int(re.search(r'(\d+)\s*weeks', text).group(1))
            return datetime.now().date() - relativedelta(weeks=weeks)
        elif 'week ago' in text:
            weeks = 1
            return datetime.now().date() - relativedelta(weeks=weeks)
        elif 'days ago' in text:
            days = int(re.search(r'(\d+)\s*days', text).group(1))
            return datetime.now().date() - timedelta(days=days)
        elif 'day ago' in text:
            days = 1
            return datetime.now().date() - timedelta(days=days)
        else:
            return None
    except AttributeError:
        return None

# Apply the extract_date function to each row and create a new 'Date' column
youtube['Date'] = youtube.apply(extract_date, axis=1)

# Display the updated DataFrame
youtube.head(10)
# Out:
#   Unnamed: 0        time              links_ID  \
# 0          0   208 views  /watch?v=NVtfCfwMpYo
# 1          1    3K views  /watch?v=s8Tl9XX1wzg
# 2          2  9.4M views  /watch?v=NVH7JewfgJg
# 3          3    35 views  /watch?v=cuFm0Yxa6MM
# 4          4   375 views  /watch?v=igss1bWgazw
# 5          5  6.8K views  /watch?v=-adgBT6mePM
# 6          6   205 views  /watch?v=92Ne7ZQTuTY
# 7          7  1.2K views  /watch?v=Qa_njs3YozA
# 8          8   34M views  /watch?v=Z7N64vUHxvw
# 9          9  4.4M views  /watch?v=TW46xDXNO3Q
#
#                          username  \
# 0                     CGTN Africa
# 1                 AFP News Agency
# 2                             Vox
# 3  South African Hindu Maha Sabha
# 4            Mzala Nxumalo Centre
# 5                      CNBCAfrica
# 6                      VOA Africa
# 7                OECD Development
# 8                 officialpsquare
# 9                   History Scope
#
#                                                title  \
# 0  Hundreds gather to discuss ways of addressing ...
# 1  South Africa's challenges by AFP News Agency 9...
# 2  Why South Africa is still so segregated by Vox...
# 3  Social challenges faced by Women of South Afri...
# 4  Challenges of Social and Economic Development ...
# 5  Challenges & opportunities facing Africa's you...
# 6  Your thoughts about girls challenges in Africa...
# 7  Challenges Africa faces after the global crisi...
# 8  P-Square - Nobody Ugly [Official Video] by off...
# 9  Why is Africa Still So Poor? by History Scope ...
#
#                                                desc1      desc2     reactions  \
# 0                                          not found  not found  no reactions
# 1  Former president Nelson Mandela retired from a...  not found  no reactions
# 2                                                  3  not found  no reactions
# 3  While reflecting on our Women's Month #LightOf...  not found  no reactions
# 4                    The Future of the Left : South   not found  no reactions
# 5  The United Nations estimates that 4 in every 1...  not found  no reactions
# 6   54's anchor Vincent Makori asked our audience...  not found  no reactions
# 7               The International Economic Forum on   not found  no reactions
# 8                                          not found  not found  no reactions
# 9                                               The   not found  no reactions
#
#                                                Texty  Views        Date
# 0  Hundreds gather to discuss ways of addressing ...    208  2019-08-24
# 1  South Africa's challenges by AFP News Agency 9...     66  2014-08-24
# 2  Why South Africa is still so segregated by Vox...    279  2022-08-24
# 3  Social challenges faced by Women of South Afri...     35  2022-08-24
# 4  Challenges of Social and Economic Development ...    375  2019-08-24
# 5  Challenges & opportunities facing Africa's you...    805  2015-08-24
# 6  Your thoughts about girls challenges in Africa...    205  2019-08-24
# 7  Challenges Africa faces after the global crisi...    255  2011-08-24
# 8  P-Square - Nobody Ugly [Official Video] by off...    311  2018-08-24
# 9  Why is Africa Still So Poor? by History Scope ...    338  2022-08-24

# %%
# Regular expression to extract the views
views_reg = r'(\d+(?:\.\d+)?(?:k)?) views'

# Function to extract views or return 0 if no match
def extract_views(text):
    match = re.search(views_reg, text, re.IGNORECASE)
    if match:
        views_text = match.group(1)
        if 'k' in views_text.lower():
            return int(float(views_text[:-1]) * 1000)
        else:
            return int(views_text.replace(',', ''))
    return 0

# Extract views using the function
youtube['Views'] = youtube['Texty'].apply(extract_views)

youtube.head()
# Out:
#   Unnamed: 0        time              links_ID  \
# 0          0   208 views  /watch?v=NVtfCfwMpYo
# 1          1    3K views  /watch?v=s8Tl9XX1wzg
# 2          2  9.4M views  /watch?v=NVH7JewfgJg
# 3          3    35 views  /watch?v=cuFm0Yxa6MM
# 4          4   375 views  /watch?v=igss1bWgazw
#
#                          username  \
# 0                     CGTN Africa
# 1                 AFP News Agency
# 2                             Vox
# 3  South African Hindu Maha Sabha
# 4            Mzala Nxumalo Centre
#
#                                                title  \
# 0  Hundreds gather to discuss ways of addressing ...
# 1  South Africa's challenges by AFP News Agency 9...
# 2  Why South Africa is still so segregated by Vox...
# 3  Social challenges faced by Women of South Afri...
# 4  Challenges of Social and Economic Development ...
#
#                                                desc1      desc2     reactions  \
# 0                                          not found  not found  no reactions
# 1  Former president Nelson Mandela retired from a...  not found  no reactions
# 2                                                  3  not found  no reactions
# 3  While reflecting on our Women's Month #LightOf...  not found  no reactions
# 4                    The Future of the Left : South   not found  no reactions
#
#                                                Texty  Views        Date
# 0  Hundreds gather to discuss ways of addressing ...    208  2019-08-24
# 1  South Africa's challenges by AFP News Agency 9...     66  2014-08-24
# 2  Why South Africa is still so segregated by Vox...    279  2022-08-24
# 3  Social challenges faced by Women of South Afri...     35  2022-08-24
# 4  Challenges of Social and Economic Development ...    375  2019-08-24

# %%
youtube.columns
# Out:
# Index(['Unnamed: 0', 'time', 'links_ID', 'username', 'title', 'desc1', 'desc2',
#        'reactions', 'Texty', 'Views'],
#       dtype='object')

# %%
youtube= youtube[['username', 'Texty','Date', 'Views']]

youtube = youtube.dropna(how='all')
youtube.head(2)
# Out:
#           username                                              Texty  \
# 0      CGTN Africa  Hundreds gather to discuss ways of addressing ...
# 1  AFP News Agency  South Africa's challenges by AFP News Agency 9...
#
#          Date  Views
# 0  2019-08-24    208
# 1  2014-08-24     66

# %%
# youtube.to_csv('D:/senego/dataafrica/oldfiles/youtube1.csv')
youtube.to_csv('/content/drive/MyDrive/Colab Notebooks/youtube1.csv')

# %%
youtube["sourcetype"] = "youtube"
youtube.head(4)
# Out:
#                          username  \
# 0                     CGTN Africa
# 1                 AFP News Agency
# 2                             Vox
# 3  South African Hindu Maha Sabha
#
#                                                Texty        Date  Views  \
# 0  Hundreds gather to discuss ways of addressing ...  2019-08-24    208
# 1  South Africa's challenges by AFP News Agency 9...  2014-08-24     66
# 2  Why South Africa is still so segregated by Vox...  2022-08-24    279
# 3  Social challenges faced by Women of South Afri...  2022-08-24     35
#
#   sourcetype
# 0    youtube
# 1    youtube
# 2    youtube
# 3    youtube

# %%
# Adding a new column "fid" with row numbers ordered by "sourcetype"
# df['fid'] = df.groupby('sourcetype').cumcount() + 1
youtube['yid'] = range(1, len(youtube) + 1)
# Displaying the first 2 rows
youtube.head(2)
# print(result)
# Out:
#           username                                              Texty  \
# 0      CGTN Africa  Hundreds gather to discuss ways of addressing ...
# 1  AFP News Agency  South Africa's challenges by AFP News Agency 9...
#
#          Date  Views sourcetype  yid
# 0  2019-08-24    208    youtube    1
# 1  2014-08-24     66    youtube    2

# %%
newyoutube_df = youtube.drop_duplicates('Texty')

# %%
newyoutube_df.shape
# Out:
# (15166, 6)

# %%
youtube.columns

# %%
youtube2 = newyoutube_df[["yid", "Date", "Texty","sourcetype","Views"]]
youtube2.head(10)
# Out:
#    yid        Date                                              Texty  \
# 0    1  2019-08-24  Hundreds gather to discuss ways of addressing ...
# 1    2  2014-08-24  South Africa's challenges by AFP News Agency 9...
# 2    3  2022-08-24  Why South Africa is still so segregated by Vox...
# 3    4  2022-08-24  Social challenges faced by Women of South Afri...
# 4    5  2019-08-24  Challenges of Social and Economic Development ...
# 5    6  2015-08-24  Challenges & opportunities facing Africa's you...
# 6    7  2019-08-24  Your thoughts about girls challenges in Africa...
# 7    8  2011-08-24  Challenges Africa faces after the global crisi...
# 8    9  2018-08-24  P-Square - Nobody Ugly [Official Video] by off...
# 9   10  2022-08-24  Why is Africa Still So Poor? by History Scope ...
#
#   sourcetype  Views
# 0    youtube    208
# 1    youtube     66
# 2    youtube    279
# 3    youtube     35
# 4    youtube    375
# 5    youtube    805
# 6    youtube    205
# 7    youtube    255
# 8    youtube    311
# 9    youtube    338

# %%
# youtube2.to_csv('D:/senego/dataafrica/oldfiles/youtube2.csv')
# youtube.to_csv('D:/senego/dataafrica/oldfiles/youtube1.csv')

youtube2.to_csv('/content/drive/MyDrive/Colab Notebooks/youtube2.csv')
youtube.to_csv('/content/drive/MyDrive/Colab Notebooks/youtube1.csv')

# %%
newyoutube_df.shape
# Out:
# (15166, 6)

# %%
newyoutube_df.columns
# Out:
# Index(['username', 'Texty', 'Date', 'Views', 'sourcetype', 'yid'], dtype='object')

# %%
youtube.columns
# Out:
# Index(['username', 'Texty', 'Date', 'Views', 'sourcetype', 'yid'], dtype='object')

# %%
youtube2 = newyoutube_df[["yid", "Date", "Texty","sourcetype","Views"]]
youtube2.head(10)
# Out:
#    yid        Date                                              Texty  \
# 0    1  2019-08-24  Hundreds gather to discuss ways of addressing ...
# 1    2  2014-08-24  South Africa's challenges by AFP News Agency 9...
# 2    3  2022-08-24  Why South Africa is still so segregated by Vox...
# 3    4  2022-08-24  Social challenges faced by Women of South Afri...
# 4    5  2019-08-24  Challenges of Social and Economic Development ...
# 5    6  2015-08-24  Challenges & opportunities facing Africa's you...
# 6    7  2019-08-24  Your thoughts about girls challenges in Africa...
# 7    8  2011-08-24  Challenges Africa faces after the global crisi...
# 8    9  2018-08-24  P-Square - Nobody Ugly [Official Video] by off...
# 9   10  2022-08-24  Why is Africa Still So Poor? by History Scope ...
#
#   sourcetype  Views
# 0    youtube    208
# 1    youtube     66
# 2    youtube    279
# 3    youtube     35
# 4    youtube    375
# 5    youtube    805
# 6    youtube    205
# 7    youtube    255
# 8    youtube    311
# 9    youtube    338

# %%
twitter=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/twitter.csv')

twitter.head()
# Out:
#                     Datetime             Tweet Id  RetweetCount  Likes  \
# 0  2019-12-19 15:30:09+00:00  1207684553512560128             0      0
# 1  2019-12-05 15:58:40+00:00  1202618297948260096            15     36
# 2  2019-12-01 14:36:11+00:00  1201147989152199936             1      8
# 3  2019-11-25 07:49:35+00:00  1198871336153730048             0      0
# 4  2019-11-21 22:00:30+00:00  1197635924617819904             0      4
#
#    Replies                                               Text language  \
# 0        0  CLIMATE SMART WATER GOVERNANCE SHARED ECOSYSTE...       en
# 1        3  READ: #OUTA says that; while universal health ...       en
# 2        1  policital and social issues.  You wanna worry ...       en
# 3        0  @WalesRugby South Africa has MANY social ills....       en
# 4        0  Opposition weaknesses are relevant to the bigg...       en
#
#           Username Unnamed: 8 Unnamed: 9  ... Unnamed: 15 Unnamed: 16  \
# 0      EngnrKarimi        NaN        NaN  ...         NaN         NaN
# 1           OUTASA        NaN        NaN  ...         NaN         NaN
# 2       goregirlfx        NaN        NaN  ...         NaN         NaN
# 3        Slipcatch        NaN        NaN  ...         NaN         NaN
# 4  mailandguardian        NaN        NaN  ...         NaN         NaN
#
#   Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20 Unnamed: 21 Unnamed: 22  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 23 Unnamed: 24
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN         NaN
#
# [5 rows x 25 columns]

# %%
twitter.columns
# Out:
# Index(['Datetime', 'Tweet Id', 'RetweetCount', 'Likes', 'Replies', 'Text',
#        'language', 'Username', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14',
#        'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
#        'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22',
#        'Unnamed: 23', 'Unnamed: 24'],
#       dtype='object')

# %%
twitter['Date']=twitter[['Datetime']]

# Calculate the "views" column and cast it to string without decimal points
twitter['Views'] = (twitter['RetweetCount'] + twitter['Likes'] + twitter['Replies']).astype(int).astype(str)

twitter=twitter[['Date','Views', 'Tweet Id', 'RetweetCount', 'Likes', 'Replies', 'Text',
       'language', 'Username']]

# %%
twitter.shape
# Out:
# (9198, 9)

# %%
twitter.to_csv('/content/drive/MyDrive/Colab Notebooks/twitter1.csv')
# twitter.head()

# %%
twitterdf= twitter[['Text','Date', 'Views']]

twitterdf = twitterdf.dropna(how='all')
twitterdf.head(2)
# Out:
#                                                 Text  \
# 0  CLIMATE SMART WATER GOVERNANCE SHARED ECOSYSTE...
# 1  READ: #OUTA says that; while universal health ...
#
#                         Date Views
# 0  2019-12-19 15:30:09+00:00     0
# 1  2019-12-05 15:58:40+00:00    54

# %%
twitterdf["sourcetype"] = "twitter"
twitterdf.head(4)
# Out:
#                                                 Text  \
# 0  CLIMATE SMART WATER GOVERNANCE SHARED ECOSYSTE...
# 1  READ: #OUTA says that; while universal health ...
# 2  policital and social issues.  You wanna worry ...
# 3  @WalesRugby South Africa has MANY social ills....
#
#                         Date Views sourcetype
# 0  2019-12-19 15:30:09+00:00     0    twitter
# 1  2019-12-05 15:58:40+00:00    54    twitter
# 2  2019-12-01 14:36:11+00:00    10    twitter
# 3  2019-11-25 07:49:35+00:00     0    twitter

# %%
# Adding a new column "fid" with row numbers ordered by "sourcetype"
# df['fid'] = df.groupby('sourcetype').cumcount() + 1
twitterdf['tid'] = range(1, len(twitter) + 1)
# Displaying the first 2 rows
twitterdf.head(2)
# print(result)
# Out:
#                                                 Text  \
# 0  CLIMATE SMART WATER GOVERNANCE SHARED ECOSYSTE...
# 1  READ: #OUTA says that; while universal health ...
#
#                         Date Views sourcetype  tid
# 0  2019-12-19 15:30:09+00:00     0    twitter    1
# 1  2019-12-05 15:58:40+00:00    54    twitter    2

# %%
twitterdf.shape
# Out:
# (9198, 5)

# %%
twitter2 = twitterdf.drop_duplicates('Text')

# %%
twitter2.shape
# Out:
# (8976, 5)

# %%
twitter2.columns
# Out:
# Index(['Text', 'Date', 'Views', 'sourcetype', 'tid'], dtype='object')

# %%
# twitter2.to_csv('D:/senego/dataafrica/oldfiles/twitter2.csv')
twitter2.to_csv('/content/drive/MyDrive/Colab Notebooks/twitter2.csv')
# twitter.head()

# %%
twitter2.head(1)
# Out:
#                                                 Text  \
# 0  CLIMATE SMART WATER GOVERNANCE SHARED ECOSYSTE...
#
#                         Date Views sourcetype  tid
# 0  2019-12-19 15:30:09+00:00     0    twitter    1

# %%
# twitter2_spark.na.drop()
# twitter2.coulmns

# %%
# facebook_df2.na.drop()
facebook2.columns
# Out:
# Index(['fid', 'Date', 'textf', 'sourcetype', 'Views'], dtype='object')

# %%
# newyoutube_df_spark2.na.drop()
youtube2.columns
# Out:
# Index(['yid', 'Date', 'Texty', 'sourcetype', 'Views'], dtype='object')

# %%
dfs = [twitter2, facebook2, youtube2]

# Concatenate DataFrames along columns
df = pd.concat(dfs, axis=0)
# df=df.dropna()
df.head(5)
# Out:
#                                                 Text  \
# 0  CLIMATE SMART WATER GOVERNANCE SHARED ECOSYSTE...
# 1  READ: #OUTA says that; while universal health ...
# 2  policital and social issues.  You wanna worry ...
# 3  @WalesRugby South Africa has MANY social ills....
# 4  Opposition weaknesses are relevant to the bigg...
#
#                         Date Views sourcetype  tid  fid textf  yid Texty
# 0  2019-12-19 15:30:09+00:00     0    twitter  1.0  NaN   NaN  NaN   NaN
# 1  2019-12-05 15:58:40+00:00    54    twitter  2.0  NaN   NaN  NaN   NaN
# 2  2019-12-01 14:36:11+00:00    10    twitter  3.0  NaN   NaN  NaN   NaN
# 3  2019-11-25 07:49:35+00:00     0    twitter  4.0  NaN   NaN  NaN   NaN
# 4  2019-11-21 22:00:30+00:00     4    twitter  5.0  NaN   NaN  NaN   NaN

# %%
df.columns
# Out:
# Index(['Text', 'Date', 'Views', 'sourcetype', 'tid', 'fid', 'textf', 'yid',
#        'Texty'],
#       dtype='object')

# %%
df.shape
# Out:
# (27581, 9)

# %%
# df['alltext']=df[['Text','textf','Texty']]
# Replace NaN values with empty strings
df[['Text', 'textf', 'Texty']] = df[['Text', 'textf', 'Texty']].fillna('')

# Concatenate the columns and create a new column 'alltext'
df['alltext'] = df['Text'] + ' ' + df['textf'] + ' ' + df['Texty']

df['textid'] = range(1, len(df) + 1)

df.head(2)
# Out:
#                                                 Text  \
# 0  CLIMATE SMART WATER GOVERNANCE SHARED ECOSYSTE...
# 1  READ: #OUTA says that; while universal health ...
#
#                         Date Views sourcetype  tid  fid textf  yid Texty  \
# 0  2019-12-19 15:30:09+00:00     0    twitter  1.0  NaN        NaN
# 1  2019-12-05 15:58:40+00:00    54    twitter  2.0  NaN        NaN
#
#                                              alltext  textid
# 0  CLIMATE SMART WATER GOVERNANCE SHARED ECOSYSTE...       1
# 1  READ: #OUTA says that; while universal health ...       2

# %%
df.columns
# Out:
# Index(['Text', 'Date', 'Views', 'sourcetype', 'tid', 'fid', 'textf', 'yid',
#        'Texty', 'alltext', 'textid'],
#       dtype='object')

# %%
df2=df[['textid','Date', 'Views','sourcetype','alltext']]
df2.shape
# Out:
# (27581, 5)

# %%
df=df2.copy()

# %%
# df.to_csv('D:/senego/dataafrica/oldfiles/socialdatacleaned2all.csv')
df.to_csv('/content/drive/MyDrive/Colab Notebooks/socialdatacleaned2all.csv')
# twitter.head()

# %%
def remove_emoticons(text):
    emoticon_pattern = re.compile(u'(' + u'|'.join(k for k in EMOTICONS) + u')')
    return emoticon_pattern.sub(r'', text)

remove_emoticons("Hello :-)")
# Out:
# 'Hello '

# %% [markdown]
# ## Conversion of Emoticon to Words
#
# In the previous step, we have removed the emoticons. In case of use cases like sentiment analysis, the emoticons give some valuable information and so removing them might not be a good solution. What can we do in such cases?
#
# One way is to convert the emoticons to word format so that they can be used in downstream modeling processes. Thanks for Neel again for the wonderful dictionary that we have used in the previous step. We are going to use that again for conversion of emoticons to words.

# %%
#df = pd.read_csv('C:/Users/Administrator/OneDrive/Documents/africa/dataafrica/socialdata.csv')
# df = pd.read_csv('D:/senego/dataafrica/oldfiles/socialdata21new.csv', encoding = "UTF-8")

# %%
df.columns
# Out:
# Index(['textid', 'Date', 'Views', 'sourcetype', 'alltext'], dtype='object')

# %%
def convert_emoticons(text):
    for emot in EMOTICONS:
        text = re.sub(u'('+emot+')', "_".join(EMOTICONS[emot].replace(",","").split()), text)
    return text


convert_emoticons("Hello :-)")
# Out:
# 'Hello Happy_face_smiley'

# %%
def convert_emoticons(text):
    for emot in EMOTICONS:
        text = re.sub(u'('+emot+')', "_".join(EMOTICONS[emot].replace(",","").split()), text)
    return text

df['Text_emt'] = df['alltext'].astype(str)
df['Text_emt'] = df['alltext'].apply(convert_emoticons)
#dataset.to_csv('output.csv',index=False, encoding='utf-8')
df['Text_emt'].head()
# Out:
# 0    CLIMATE SMART WATER GOVERNANCE SHARED ECOSYSTE...
# 1    REASadness #OUTA says that; while universal he...
# 2    policital and social issues.  You wanna worry ...
# 3    @WalesRugby South Africa has MANY social ills....
# 4    Opposition weaknesses are relevant to the bigg...
# Name: Text_emt, dtype: object

# %%
df.head(10)
# Out:
#   textid                       Date Views sourcetype  \
# 0      1  2019-12-19 15:30:09+00:00     0    twitter
# 1      2  2019-12-05 15:58:40+00:00    54    twitter
# 2      3  2019-12-01 14:36:11+00:00    10    twitter
# 3      4  2019-11-25 07:49:35+00:00     0    twitter
# 4      5  2019-11-21 22:00:30+00:00     4    twitter
# 5      6  2019-11-18 10:17:15+00:00     2    twitter
# 6      7  2019-11-12 16:08:48+00:00     0    twitter
# 7      8  2019-11-05 16:26:24+00:00     0    twitter
# 8      9  2019-10-31 15:09:28+00:00     2    twitter
# 9     10  2019-10-24 07:23:50+00:00    23    twitter
#
#                                              alltext  \
# 0  CLIMATE SMART WATER GOVERNANCE SHARED ECOSYSTE...
# 1  READ: #OUTA says that; while universal health ...
# 2  policital and social issues.  You wanna worry ...
# 3  @WalesRugby South Africa has MANY social ills....
# 4  Opposition weaknesses are relevant to the bigg...
# 5  @vcmcguire Yes; I know someone in South Africa...
# 6  @chuks_okereke A huge concern for social susta...
# 7  @SitshelaN @misazimbabwe @SANGONeT @OSISA And ...
# 8  @ebohinson The professor is this interview mak...
# 9  Malawi National Council of Sports has expresse...
#
#                                             Text_emt
# 0  CLIMATE SMART WATER GOVERNANCE SHARED ECOSYSTE...
# 1  REASadness #OUTA says that; while universal he...
# 2  policital and social issues.  You wanna worry ...
# 3  @WalesRugby South Africa has MANY social ills....
# 4  Opposition weaknesses are relevant to the bigg...
# 5  @vcmcguire Yes; I know someone in South Africa...
# 6  @chuks_okereke A huge concern for social susta...
# 7  @SitshelaN @misazimbabwe @SANGONeT @OSISA And ...
# 8  @ebohinson The professor is this interview mak...
# 9  Malawi National Council of Sports has expresse...

# %%
text = "I am sad :()"
convert_emoticons(text)
# Out:
# 'I am sad Frown_sad_andry_or_poutingConfusion'

# %% [markdown]
# This method might be better for some use cases when we do not want to miss out on the emoticon information.
#
# ## Conversion of Emoji to Words
#
# Now let us do the same for Emojis as well. Neel Shah has put together a list of emojis with the corresponding words as well as part of his [Github repo](https://github.com/NeelShah18/emot/blob/master/emot/emo_unicode.py). We are going to make use of this dictionary to convert the emojis to corresponding words.
#
# Again this conversion might be better than emoji removal for certain use cases. Please use the one that is suitable for the use case.

# %%
def convert_emoticons(text):
    for emot in EMOTICONS:
        text = re.sub(u'('+emot+')', "_".join(EMOTICONS[emot].replace(",","").split()), text)
    return text

text = "Hello :-) :-)"
convert_emoticons(text)
# Out:
# 'Hello Happy_face_smiley Happy_face_smiley'

# %%
def convert_emojis(text):
    for emot in UNICODE_EMO:
        text = re.sub(r'('+emot+')', "_".join(UNICODE_EMO[emot].replace(",","").replace(":","").split()), text)
    return text

text = "EP1 ➡️ La ville vue par les "
#"game is on 🔥"
convert_emojis(text)
# Out:
# 'EP1 right_arrow️ La ville vue par les '

# %%
text = "🔴 Top 30 countries in vaccinations against COVID-19 (updated April 29th 2021)"
convert_emojis(text)
# Out:
# 'red_circle Top 30 countries in vaccinations against COVID-19 (updated April 29th 2021)'

# %%
#from emot import EMOTICONS

def convert_emojis(text):
    for emot in UNICODE_EMO:
        text = re.sub(r'('+emot+')', "_".join(UNICODE_EMO[emot].replace(",","").replace(":","").split()), text)
    return text
df['Text_emj'] = df['Text_emt'].astype(str)
df['Text_emj'] = df['Text_emt'].apply(convert_emojis)
#dataset.to_csv('output.csv',index=False, encoding='utf-8')
df['Text_emj'].head()
# Out:
# 0    CLIMATE SMART WATER GOVERNANCE SHARED ECOSYSTE...
# 1    REASadness #OUTA says that; while universal he...
# 2    policital and social issues.  You wanna worry ...
# 3    @WalesRugby South Africa has MANY social ills....
# 4    Opposition weaknesses are relevant to the bigg...
# Name: Text_emj, dtype: object

# %%
df.head(10)
# Out:
#   textid                       Date Views sourcetype  \
# 0      1  2019-12-19 15:30:09+00:00     0    twitter
# 1      2  2019-12-05 15:58:40+00:00    54    twitter
# 2      3  2019-12-01 14:36:11+00:00    10    twitter
# 3      4  2019-11-25 07:49:35+00:00     0    twitter
# 4      5  2019-11-21 22:00:30+00:00     4    twitter
# 5      6  2019-11-18 10:17:15+00:00     2    twitter
# 6      7  2019-11-12 16:08:48+00:00     0    twitter
# 7      8  2019-11-05 16:26:24+00:00     0    twitter
# 8      9  2019-10-31 15:09:28+00:00     2    twitter
# 9     10  2019-10-24 07:23:50+00:00    23    twitter
#
#                                              alltext  \
# 0  CLIMATE SMART WATER GOVERNANCE SHARED ECOSYSTE...
# 1  READ: #OUTA says that; while universal health ...
# 2  policital and social issues.  You wanna worry ...
# 3  @WalesRugby South Africa has MANY social ills....
# 4  Opposition weaknesses are relevant to the bigg...
# 5  @vcmcguire Yes; I know someone in South Africa...
# 6  @chuks_okereke A huge concern for social susta...
# 7  @SitshelaN @misazimbabwe @SANGONeT @OSISA And ...
# 8  @ebohinson The professor is this interview mak...
# 9  Malawi National Council of Sports has expresse...
#
#                                             Text_emt  \
# 0  CLIMATE SMART WATER GOVERNANCE SHARED ECOSYSTE...
# 1  REASadness #OUTA says that; while universal he...
# 2  policital and social issues.  You wanna worry ...
# 3  @WalesRugby South Africa has MANY social ills....
# 4  Opposition weaknesses are relevant to the bigg...
# 5  @vcmcguire Yes; I know someone in South Africa...
# 6  @chuks_okereke A huge concern for social susta...
# 7  @SitshelaN @misazimbabwe @SANGONeT @OSISA And ...
# 8  @ebohinson The professor is this interview mak...
# 9  Malawi National Council of Sports has expresse...
#
#                                             Text_emj
# 0  CLIMATE SMART WATER GOVERNANCE SHARED ECOSYSTE...
# 1  REASadness #OUTA says that; while universal he...
# 2  policital and social issues.  You wanna worry ...
# 3  @WalesRugby South Africa has MANY social ills....
# 4  Opposition weaknesses are relevant to the bigg...
# 5  @vcmcguire Yes; I know someone in South Africa...
# 6  @chuks_okereke A huge concern for social susta...
# 7  @SitshelaN @misazimbabwe @SANGONeT @OSISA And ...
# 8  @ebohinson The professor is this interview mak...
# 9  Malawi National Council of Sports has expresse...

# %%
#df1= df.copy()
shuffled = df.sample(frac=1)
shuffled.head(10)
# Out:
#       textid                       Date Views sourcetype  \
# 81     12497                 2016-08-24    15    youtube
# 1092    9877        2020-05-06 00:00:00   159   facebook
# 7243   18504                 2021-08-24   483    youtube
# 674      669  2019-07-11 14:39:44+00:00    12    twitter
# 13376  23222                 2023-02-24   803    youtube
# 4388    4304  2020-12-21 18:00:48+00:00    20    twitter
# 6897   18196                 2023-05-24   222    youtube
# 1099    1093  2019-12-09 08:00:00+00:00     0    twitter
# 8300   19265                 2022-08-24   899    youtube
# 1614   13929                 2023-08-19   375    youtube
#
#                                                  alltext  \
# 81       The Story of Ebola by Global Health Media Pr...
# 1092    ALABA COMMUNITY HEAD DEBUNKS OONI'S INVOLVEME...
# 7243     Our Planet | Frozen Worlds | FULL EPISODE | ...
# 674    @CoolGains Best and the most powerful  spiritu...
# 13376    ASKING LEARNER'S QUESTIONS! (SCHOOL EDITION)...
# 4388   @pesa_africa @potentash He asked genuine quest...
# 6897     Dr. Oz Makes Shocking Abortion Comment in Fe...
# 1099   "Through PfP; an educational initiative; Symph...
# 8300     WATCH: What is critical race theory? by PBS ...
# 1614     Watch Live: 2023 State of the Union Address ...
#
#                                                 Text_emt  \
# 81       The Story of Ebola by Global Health Media Pr...
# 1092    ALABA COMMUNITY HEAD DEBUNKS OONI'S INVOLVEME...
# 7243     Our Planet | Frozen Worlds | FULL EPISODE | ...
# 674    @CoolGains Best and the most powerful  spiritu...
# 13376    ASKING LEARNER'S QUESTIONS! (SCHOOL EDITIONC...
# 4388   @pesa_africa @potentash He asked genuine quest...
# 6897     Dr. Oz Makes Shocking Abortion Comment in Fe...
# 1099   "Through PfP; an educational initiative; Symph...
# 8300     WATCH: What is critical race theory? by PBS ...
# 1614     Watch Live: 2023 State of the Union Address ...
#
#                                                 Text_emj
# 81       The Story of Ebola by Global Health Media Pr...
# 1092    ALABA COMMUNITY HEAD DEBUNKS OONI'S INVOLVEME...
# 7243     Our Planet | Frozen Worlds | FULL EPISODE | ...
# 674    @CoolGains Best and the most powerful  spiritu...
# 13376    ASKING LEARNER'S QUESTIONS! (SCHOOL EDITIONC...
# 4388   @pesa_africa @potentash He asked genuine quest...
# 6897     Dr. Oz Makes Shocking Abortion Comment in Fe...
# 1099   "Through PfP; an educational initiative; Symph...
# 8300     WATCH: What is critical race theory? by PBS ...
# 1614     Watch Live: 2023 State of the Union Address ...

# %%
# !pip install langdetect

# !pip install langid
# !pip install deep_translator
# Out:
# Requirement already satisfied: langdetect in /usr/local/lib/python3.10/dist-packages (1.0.9)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from langdetect) (1.16.0)
# Collecting langid
#   Downloading langid-1.1.6.tar.gz (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 20.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from langid) (1.23.5)
# Building wheels for collected packages: langid
#   Building wheel for langid (setup.py) ... done
#   Created wheel for langid: filename=langid-1.1.6-py3-none-any.whl size=1941172 sha256=9e3aaba78ff65a17d22cf4238a6322f7a73a2f3f3ddde9d0f66b931d82e11800
#   Stored in directory: /root/.cache/pip/wheels/23/c8/c6/eed80894918490a175677414d40bd7c851413bbe03d4856c3c
# Successfully built langid
# Installing collected packages: langid
# Successfully installed langid-1.1.6
# Requirement already satisfied: deep_translator in /usr/local/lib/python3.10/dist-packages (1.11.4)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from deep_translator) (4.11.2)
# Requirement already satisfied: requests<3.0.0,>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from deep_translator) (2.31.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep_translator) (2.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep_translator) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep_translator) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep_translator) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep_translator) (2023.7.22)

# %%
# Detect and convert languages
from langdetect import detect
def detect_my(text):
   try:
       return detect(text)
   except:
       return 'unknown'
df['Text_langue'] = df['Text_emj'].apply(detect_my)
df['Text_langue'].head(2)
# Out:
# 0    en
# 1    en
# Name: Text_langue, dtype: object

# %%
# df.to_csv("D:/senego/dataafrica/oldfiles/socialdatacleaned2allemoji.csv", encoding = "UTF-8")
df.to_csv("/content/drive/MyDrive/Colab Notebooks/socialdatacleaned2allemoji.csv", encoding = "UTF-8")
# df=df.astype(str)

# %%
df_new=df['Text_langue'].value_counts().reset_index()#.plot(kind='bar')

# %%
df_new=df['Text_langue'].value_counts().reset_index()#.plot(kind='bar')
ax = sns.barplot(x='Text_langue', y='index', data=df_new)
ax.set_title('Count of records for all languages in data')
ax.set_xlabel('Languages in data')
ax.set_ylabel('Number of count')
plt.show()

# %%
textdf=df

# %%
train_en = textdf[textdf['Text_langue'] == 'en']
train_not_en = textdf[textdf['Text_langue'] != 'en']

# %%
train_not_en.head(10)
# Out:
#      textid                       Date Views sourcetype  \
# 582     577  2019-08-08 08:58:27+00:00     8    twitter
# 1139   1133  2019-11-22 07:50:43+00:00     3    twitter
# 1150   1144  2019-11-19 08:48:39+00:00    20    twitter
# 1182   1173  2019-11-04 06:30:17+00:00     6    twitter
# 1246   1237  2019-10-02 15:58:27+00:00     8    twitter
# 1275   1265  2019-09-25 08:50:56+00:00     3    twitter
# 1390   1375  2019-08-02 06:30:07+00:00     0    twitter
# 1413   1398  2019-07-23 11:01:13+00:00     0    twitter
# 1419   1404  2019-07-19 12:39:18+00:00    15    twitter
# 1461   1446  2019-06-26 04:41:45+00:00     8    twitter
#
#                                                 alltext  \
# 582
# 1139  Bonjour @africatechie; je repensais Ã  votre p...
# 1150  #ECONOMÃAðŸ‡²ðŸ‡¦_x000D_\n_x000D_\nEn la reun...
# 1182  Dans le cadre de l'Africa Basque Challenge don...
# 1246  Tu as entre 18 et 45 ans ?_x000D_\n_x000D_\nTu...
# 1275  Lâ€™ESTIA co-organise une initiative dÃ©nommÃ©...
# 1390  ð—¥ð—¼ð˜€ð—¸ð—¶ð—¹ð—¹ ðŸ§—â€â™€ï¸ðŸ¤...
# 1413  APPLY: Better Together Challenge 2019 for youn...
# 1419  Better Together Challenge 2019 for young Chang...
# 1461                        Exploring biological &amp
#
#                                                Text_emt  \
# 582
# 1139  Bonjour @africatechie; je repensais Ã  votre p...
# 1150  #ECONOMÃAðŸ‡²ðŸ‡¦_x000D_\n_x000D_\nEn la reun...
# 1182  Dans le cadre de l'Africa Basque Challenge don...
# 1246  Tu as entre 18 et 45 ans ?_x000D_\n_x000D_\nTu...
# 1275  Lâ€™ESTIA co-organise une initiative dÃ©nommÃ©...
# 1390  ð—¥ð—¼ð˜€ð—¸ð—¶ð—¹ð—¹ ðŸ§—â€â™€ï¸ðŸ¤...
# 1413  APPLY: Better Together Challenge 2019 for youn...
# 1419  Better Together Challenge 2019 for young Chang...
# 1461                        Exploring biological &amp
#
#                                                Text_emj Text_langue
# 582                                                         unknown
# 1139  Bonjour @africatechie; je repensais Ã  votre p...          fr
# 1150  #ECONOMÃAðŸ‡²ðŸ‡¦_x000D_\n_x000D_\nEn la reun...          es
# 1182  Dans le cadre de l'Africa Basque Challenge don...          fr
# 1246  Tu as entre 18 et 45 ans ?_x000D_\n_x000D_\nTu...          fr
# 1275  Lâ€trade_markESTIA co-organise une initiative ...          fr
# 1390  ð—¥ð—¼ð˜€ð—¸ð—¶ð—¹ð—¹ ðŸ§—â€âtrade_mar...          de
# 1413  APPLY: Better Together Challenge 2019 for youn...          no
# 1419  Better Together Challenge 2019 for young Chang...          no
# 1461                        Exploring biological &amp            ro

# %%
# Identify and remove missing values
train_not_en.isna().head()
# Out:
#       textid   Date  Views  sourcetype  alltext  Text_emt  Text_emj  \
# 582    False  False  False       False    False     False     False
# 1139   False  False  False       False    False     False     False
# 1150   False  False  False       False    False     False     False
# 1182   False  False  False       False    False     False     False
# 1246   False  False  False       False    False     False     False
#
#       Text_langue
# 582         False
# 1139        False
# 1150        False
# 1182        False
# 1246        False

# %%
# Translating text not in English
from deep_translator import GoogleTranslator
import langid
len_data = len( train_not_en)
# For each article, we detect its language; if it's not English,
# we ask Google Translate to translate it into English, otherwise we keep the source text
gt = GoogleTranslator(source='auto', target='en')
max_art_len = 1000  # Here, we truncate the content to first 1000 characters; Google Translate accepts texts
                    # not longer than 5000 characters, but the volume of 1000 can be enough for classification
                    # and enables us to reduce the time of working with translation service

translated_arts = []

for i in range(len( train_not_en)):
    if i % 200 == 0:
        print(f"Translated {i} / {len_data}")
    cur_art =  train_not_en.iloc[i]['Text_emj'][:max_art_len]
    translated_arts.append(cur_art if langid.classify(cur_art)[0] == 'en' else gt.translate(cur_art))

train_not_en['Text_translate'] = translated_arts
# Out:
# Translated 0 / 194
# <ipython-input-144-d1204cde3e73>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_not_en['Text_translate'] = translated_arts

# %%
# Detect and convert languages
from langdetect import detect
def detect_my(text):
   try:
       return detect(text)
   except:
       return 'unknown'
train_not_en['Text_langue2'] = train_not_en['Text_translate'].apply(detect_my)
train_not_en['Text_langue2'].head(2)
# Out:
# <ipython-input-145-f63cab85e60e>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_not_en['Text_langue2'] = train_not_en['Text_translate'].apply(detect_my)
# 582     unknown
# 1139         en
# Name: Text_langue2, dtype: object

# %%
df_new2=train_not_en['Text_langue2'].value_counts().reset_index()#.plot(kind='bar')
ax = sns.barplot(x='Text_langue2', y='index', data=df_new2)
ax.set_title('Count of records for all languages in data')
ax.set_xlabel('Languages in data')
ax.set_ylabel('Number of count')
plt.show()

# %%
# # We can compare source and translated articles
# #train_not_en.head(10)
# shuffled = train_not_en.sample(frac=1)
# shuffled.head(10)

# %%
train_not_en.head(10)
# Out:
#      textid                       Date Views sourcetype  \
# 582     577  2019-08-08 08:58:27+00:00     8    twitter
# 1139   1133  2019-11-22 07:50:43+00:00     3    twitter
# 1150   1144  2019-11-19 08:48:39+00:00    20    twitter
# 1182   1173  2019-11-04 06:30:17+00:00     6    twitter
# 1246   1237  2019-10-02 15:58:27+00:00     8    twitter
# 1275   1265  2019-09-25 08:50:56+00:00     3    twitter
# 1390   1375  2019-08-02 06:30:07+00:00     0    twitter
# 1413   1398  2019-07-23 11:01:13+00:00     0    twitter
# 1419   1404  2019-07-19 12:39:18+00:00    15    twitter
# 1461   1446  2019-06-26 04:41:45+00:00     8    twitter
#
#                                                 alltext  \
# 582
# 1139  Bonjour @africatechie; je repensais Ã  votre p...
# 1150  #ECONOMÃAðŸ‡²ðŸ‡¦_x000D_\n_x000D_\nEn la reun...
# 1182  Dans le cadre de l'Africa Basque Challenge don...
# 1246  Tu as entre 18 et 45 ans ?_x000D_\n_x000D_\nTu...
# 1275  Lâ€™ESTIA co-organise une initiative dÃ©nommÃ©...
# 1390  ð—¥ð—¼ð˜€ð—¸ð—¶ð—¹ð—¹ ðŸ§—â€â™€ï¸ðŸ¤...
# 1413  APPLY: Better Together Challenge 2019 for youn...
# 1419  Better Together Challenge 2019 for young Chang...
# 1461                        Exploring biological &amp
#
#                                                Text_emt  \
# 582
# 1139  Bonjour @africatechie; je repensais Ã  votre p...
# 1150  #ECONOMÃAðŸ‡²ðŸ‡¦_x000D_\n_x000D_\nEn la reun...
# 1182  Dans le cadre de l'Africa Basque Challenge don...
# 1246  Tu as entre 18 et 45 ans ?_x000D_\n_x000D_\nTu...
# 1275  Lâ€™ESTIA co-organise une initiative dÃ©nommÃ©...
# 1390  ð—¥ð—¼ð˜€ð—¸ð—¶ð—¹ð—¹ ðŸ§—â€â™€ï¸ðŸ¤...
# 1413  APPLY: Better Together Challenge 2019 for youn...
# 1419  Better Together Challenge 2019 for young Chang...
# 1461                        Exploring biological &amp
#
#                                                Text_emj Text_langue  \
# 582                                                         unknown
# 1139  Bonjour @africatechie; je repensais Ã  votre p...          fr
# 1150  #ECONOMÃAðŸ‡²ðŸ‡¦_x000D_\n_x000D_\nEn la reun...          es
# 1182  Dans le cadre de l'Africa Basque Challenge don...          fr
# 1246  Tu as entre 18 et 45 ans ?_x000D_\n_x000D_\nTu...          fr
# 1275  Lâ€trade_markESTIA co-organise une initiative ...          fr
# 1390  ð—¥ð—¼ð˜€ð—¸ð—¶ð—¹ð—¹ ðŸ§—â€âtrade_mar...          de
# 1413  APPLY: Better Together Challenge 2019 for youn...          no
# 1419  Better Together Challenge 2019 for young Chang...          no
# 1461                        Exploring biological &amp            ro
#
#                                          Text_translate Text_langue2
# 582                                                          unknown
# 1139  Hello @africatechie; I was thinking about your...           en
# 1150  #ECONOMÃAðŸ‡²ðŸ‡¦_x000D_\n_x000D_\nAt the meet...           en
# 1182  Within the framework of the Africa Basque Chal...           en
# 1246  Are you between 18 and 45?_x000D_\n_x000D_\nDo...           en
# 1275  Lâ€trade_markESTIA co-organizes a copyright in...           en
# 1390  ð—¥ð—¼ð˜€ð—¸ð—¶ð—¹ð—¹ ðŸ§—â€âtrade_mark€ï¸ðŸ¤ ...           en
# 1413  APPLY: Better Together Challenge 2019 for youn...           no
# 1419  Better Together Challenge 2019 for young Chang...           no
# 1461                        Exploring biological &amp             ro

# %%
train_not_en.columns
# Out:
# Index(['textid', 'Date', 'Views', 'sourcetype', 'alltext', 'Text_emt',
#        'Text_emj', 'Text_langue', 'Text_translate', 'Text_langue2'],
#       dtype='object')

# %%
df_drop=train_not_en[['textid', 'Text', 'sourcetype',
       'Text_langue', 'Text_translate', 'Text_langue2']]
df_drop.head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-150-7e8d6fc0da0f> in <cell line: 1>()
# ----> 1 df_drop=train_not_en[['textid', 'Text', 'sourcetype',
#       2        'Text_langue', 'Text_translate', 'Text_langue2']]
#       3 df_drop.head(10)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3811             if is_iterator(key):
#    3812                 key = list(key)
# -> 3813             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3814
#    3815         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6068             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6069
# -> 6070         self._raise_if_missing(keyarr, indexer, axis_name)
#    6071
#    6072         keyarr = self.take(indexer)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _raise_if_missing(self, key, indexer, axis_name)
#    6131
#    6132             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6133             raise KeyError(f"{not_found} not in index")
#    6134
#    6135     @overload
#
# KeyError: "['Text'] not in index"

# %%
train_en2 = train_not_en[train_not_en['Text_langue2'] == 'en']
train_not_en2 = train_not_en[train_not_en['Text_langue2'] != 'en']

# %%
# Remove column name 'A'
#train_not_en = train_not_en.drop(['Text_translated'], axis=1)
train_not_en2
# Out:
#       textid                       Date Views sourcetype  \
# 582      577  2019-08-08 08:58:27+00:00     8    twitter
# 1413    1398  2019-07-23 11:01:13+00:00     0    twitter
# 1419    1404  2019-07-19 12:39:18+00:00    15    twitter
# 1461    1446  2019-06-26 04:41:45+00:00     8    twitter
# 2413    2371  2020-10-28 13:30:10+00:00     2    twitter
# 3183    3134  2020-04-02 15:47:02+00:00     0    twitter
# 6245    6107  2021-06-10 09:17:17+00:00   195    twitter
# 6247    6109  2021-06-09 23:21:49+00:00   278    twitter
# 7605    7428  2022-06-30 13:35:09+00:00     6    twitter
# 125     9102                       None     0   facebook
# 130     9103                       None     0   facebook
# 342     9244                       None     0   facebook
# 507     9403                       None  1300   facebook
# 616     9486                       None     9   facebook
# 756     9625                       None     0   facebook
# 766     9632                       None     0   facebook
# 772     9633                       None   674   facebook
# 819     9675                       None   852   facebook
# 851     9706                       None     0   facebook
# 854     9709                       None     0   facebook
# 890     9737                       None     0   facebook
# 936     9764                       None     0   facebook
# 959     9778                       None     0   facebook
# 986     9796                       None     0   facebook
# 1022    9814                       None   680   facebook
# 1155    9916                       None     0   facebook
# 1164    9917                       None    15   facebook
# 1333   10052                       None     0   facebook
# 1336   10053                       None   499   facebook
# 1564   10232                       None     0   facebook
# 2617   11040        2022-06-03 00:00:00   116   facebook
# 2787   11204        2022-09-23 00:00:00  1100   facebook
# 3151   11420        2019-01-05 00:00:00     0   facebook
# 3186   11424                       None     0   facebook
# 3389   11440                       None   170   facebook
# 3421   11461                       None  1700   facebook
# 3519   11545                       None     0   facebook
# 3617   11632                       None   369   facebook
# 3664   11671                       None  1500   facebook
# 3740   11740        2022-10-10 00:00:00   471   facebook
# 3781   11748                       None     0   facebook
# 3874   11749                       None   128   facebook
# 4040   11903                       None     0   facebook
# 4359   12158                       None     0   facebook
# 7060   18339                 2017-08-24   604    youtube
# 13658  23478                 2017-08-24   690    youtube
#
#                                                  alltext  \
# 582
# 1413   APPLY: Better Together Challenge 2019 for youn...
# 1419   Better Together Challenge 2019 for young Chang...
# 1461                         Exploring biological &amp
# 2413                                          Live &gt
# 3183             @Unathi_Kwaza I'm touched Unathi &amp
# 6245                                     #Eritrea &amp
# 6247                                    #Ethiopia &amp
# 7605                                       Social &amp
# 125                                     nannannannannan
# 130                                    nannannannan2022
# 342                               nannannannan Botswan"
# 507     nannannannanSuid Afrika South AfricaFeb 9 · 1...
# 616     nannannannanAyòdélé Adéfowópè AdébósìnMar 13,...
# 756     nannannannan over 3000 rural farmers have bee...
# 766     nannannannan/gregg.fick/videos/33966311503658...
# 772      nannannannanGregg FickMay 12, 2020 · 674 views
# 819     nannannannanZimbabweYadzoka/MayibuyeiZimbabwe...
# 851                                nannannannanOPEN 656
# 854                                nannannannanOPEN 352
# 890                       nannannannan against all odds
# 936                         nannannannan if it's true "
# 959                                    nannannannan2019
# 986                                    nannannannan re"
# 1022     nannannannanGregg FickMay 12, 2020 · 680 views
# 1155    nannannannan/sarala.rajendran/videos/37331836...
# 1164    nannannannanSarala RajendranApr 4, 2022 · 15 ...
# 1333    nannannannan/phindile.george/videos/691405748...
# 1336    nannannannanPhindile George ZibulaMar 4, 2022...
# 1564                           nannannannanBinary robot
# 2617    Group 1\nPhilippine Social Problems on Corrup...
# 2787    ✅\nInternational Nutrition Olympiad\nVideo le...
# 3151          nannannannan 1/5/2019] Yetunde: Very good
# 3186                                    nannannannan 1"
# 3389    nannannannanP   r   i   n   c   Y   o   r   k...
# 3421    nannannannanWork Permits VisaJan 20 · 1.7K vi...
# 3519                                   nannannannan 20"
# 3617    nannannannanWork Permit Visa Agent & Visa Con...
# 3664    nannannannanWork Permit Visa Agent & Visa Con...
# 3740    WEB DEVELOPMENT FULL COURSE\nKhris Digital Ac...
# 3781    nannannannan/watch/?ref=search&v=754234982258...
# 3874    nannannannanP   r   i   n   c   Y   o   r   k...
# 4040                               nannannannanOPEN 479
# 4359    nannannannan/texan.buddha/videos/334083218263...
# 7060     Mundo Bita - Meu Pequeno Coração by Mundo Bi...
# 13658    Mundo Bita - Meu Pequeno Coração by Mundo Bi...
#
#                                                 Text_emt  \
# 582
# 1413   APPLY: Better Together Challenge 2019 for youn...
# 1419   Better Together Challenge 2019 for young Chang...
# 1461                         Exploring biological &amp
# 2413                                          Live &gt
# 3183             @Unathi_Kwaza I'm touched Unathi &amp
# 6245                                     #Eritrea &amp
# 6247                                    #Ethiopia &amp
# 7605                                       Social &amp
# 125                                     nannannannannan
# 130                                    nannannannan2022
# 342                               nannannannan Botswan"
# 507     nannannannanSuid Afrika South AfricaFeb 9 · 1...
# 616     nannannannanAyòdélé Adéfowópè AdébósìnMar 13,...
# 756     nannannannan over 3000 rural farmers have bee...
# 766     nannannannan/gregg.fick/videos/33966311503658...
# 772      nannannannanGregg FickMay 12, 2020 · 674 views
# 819     nannannannanZimbabweYadzoka/MayibuyeiZimbabwe...
# 851                                nannannannanOPEN 656
# 854                                nannannannanOPEN 352
# 890                       nannannannan against all odds
# 936                         nannannannan if it's true "
# 959                                    nannannannan2019
# 986                                    nannannannan re"
# 1022     nannannannanGregg FickMay 12, 2020 · 680 views
# 1155    nannannannan/sarala.rajendran/videos/37331836...
# 1164    nannannannanSarala RajendranApr 4, 2022 · 15 ...
# 1333    nannannannan/phindile.george/videos/691405748...
# 1336    nannannannanPhindile George ZibulaMar 4, 2022...
# 1564                           nannannannanBinary robot
# 2617    Group 1\nPhilippine Social Problems on Corrup...
# 2787    ✅\nInternational Nutrition Olympiad\nVideo le...
# 3151          nannannannan 1/5/2019] Yetunde: Very good
# 3186                                    nannannannan 1"
# 3389    nannannannanP   r   i   n   c   Y   o   r   k...
# 3421    nannannannanWork Permits VisaJan 20 · 1.7K vi...
# 3519                                   nannannannan 20"
# 3617    nannannannanWork Permit Visa Agent & Visa Con...
# 3664    nannannannanWork Permit Visa Agent & Visa Con...
# 3740    WEB DEVELOPMENT FULL COURSE\nKhris Digital Ac...
# 3781    nannannannan/watch/?ref=search&v=754234982258...
# 3874    nannannannanP   r   i   n   c   Y   o   r   k...
# 4040                               nannannannanOPEN 479
# 4359    nannannannan/texan.buddha/videos/334083218263...
# 7060     Mundo Bita - Meu Pequeno Coração by Mundo Bi...
# 13658    Mundo Bita - Meu Pequeno Coração by Mundo Bi...
#
#                                                 Text_emj Text_langue  \
# 582                                                          unknown
# 1413   APPLY: Better Together Challenge 2019 for youn...          no
# 1419   Better Together Challenge 2019 for young Chang...          no
# 1461                         Exploring biological &amp            ro
# 2413                                          Live &gt            da
# 3183             @Unathi_Kwaza I'm touched Unathi &amp            sw
# 6245                                     #Eritrea &amp            ro
# 6247                                    #Ethiopia &amp            sw
# 7605                                       Social &amp            ca
# 125                                     nannannannannan           fi
# 130                                    nannannannan2022           tl
# 342                               nannannannan Botswan"           tl
# 507     nannannannanSuid Afrika South AfricaFeb 9 · 1...          af
# 616     nannannannanAyòdélé Adéfowópè AdébósìnMar 13,...          fr
# 756     nannannannan over 3000 rural farmers have bee...          no
# 766     nannannannan/gregg.fick/videos/33966311503658...          sv
# 772      nannannannanGregg FickMay 12, 2020 · 674 views           tl
# 819     nannannannanZimbabweYadzoka/MayibuyeiZimbabwe...          sw
# 851                                nannannannanOPEN 656           fi
# 854                                nannannannanOPEN 352           fi
# 890                       nannannannan against all odds           sv
# 936                         nannannannan if it's true "           fr
# 959                                    nannannannan2019           fi
# 986                                    nannannannan re"           fi
# 1022     nannannannanGregg FickMay 12, 2020 · 680 views           tl
# 1155    nannannannan/sarala.rajendran/videos/37331836...          fi
# 1164    nannannannanSarala RajendranApr 4, 2022 · 15 ...          sv
# 1333    nannannannan/phindile.george/videos/691405748...          et
# 1336    nannannannanPhindile George ZibulaMar 4, 2022...          de
# 1564                           nannannannanBinary robot           tl
# 2617    Group 1\nPhilippine Social Problems on Corrup...          ko
# 2787    white_heavy_check_mark\nInternational Nutriti...          ko
# 3151          nannannannan 1/5/2019] Yetunde: Very good           cy
# 3186                                    nannannannan 1"           tl
# 3389    nannannannanP   r   i   n   c   Y   o   r   k...          cy
# 3421    nannannannanWork Permits VisaJan 20 · 1.7K vi...          fi
# 3519                                   nannannannan 20"           fi
# 3617    nannannannanWork Permit Visa Agent & Visa Con...          fi
# 3664    nannannannanWork Permit Visa Agent & Visa Con...          fi
# 3740    WEB DEVELOPMENT FULL COURSE\nKhris Digital Ac...          ko
# 3781    nannannannan/watch/?ref=search&v=754234982258...          ca
# 3874    nannannannanP   r   i   n   c   Y   o   r   k...          cy
# 4040                               nannannannanOPEN 479           fi
# 4359    nannannannan/texan.buddha/videos/334083218263...          sv
# 7060     Mundo Bita - Meu Pequeno Coração by Mundo Bi...          pt
# 13658    Mundo Bita - Meu Pequeno Coração by Mundo Bi...          pt
#
#                                           Text_translate Text_langue2
# 582                                                           unknown
# 1413   APPLY: Better Together Challenge 2019 for youn...           no
# 1419   Better Together Challenge 2019 for young Chang...           no
# 1461                         Exploring biological &amp             ro
# 2413                                            Live &gt           da
# 3183             @Unathi_Kwaza I'm touched Unathi &amp             sw
# 6245                                     #Eritrea &amp             ro
# 6247                                    #Ethiopia &amp             sw
# 7605                                       Social &amp             ca
# 125                                         nannannannan           tl
# 130                                    nannannannan2022            fi
# 342                                nannannannan Botswan"           tl
# 507    nannannanSuid Afrika South AfricaFeb 9 · 1.3K ...           af
# 616    nannannanAyodéle Adéfópe AdébósinMar 13, 2021 ...           fr
# 756     nannannannan over 3000 rural farmers have bee...           no
# 766     nannannannan/gregg.fick/videos/3396631150365848/           sv
# 772       nannannannanGregg FickMay 12, 2020 · 674 views           tl
# 819    nannannanZimbabweYadzoka/MayibuyeiZimbabweSep ...           sw
# 851                                nannannannanOPEN 656            fi
# 854                                nannannannanOPEN 352            fi
# 890                           nannannan against all odds           cy
# 936                         nannannannan if it's true "            fr
# 959                                    nannannannan2019            fi
# 986                                        nannannan re"           tl
# 1022      nannannannanGregg FickMay 12, 2020 · 680 views           tl
# 1155   nannannannan/sarala.rajendran/videos/373318368...           fi
# 1164     nannannanSarala RajendranApr 4, 2022 · 15 views           sv
# 1333    nannannannan/phindile.george/videos/691405748...           et
# 1336   nannannanPhindile George ZibulaMar 4, 2022 · 4...           de
# 1564                           nannannannanBinary robot            tl
# 2617   Group 1\nPhilippine Social Problems on Corrupt...      unknown
# 2787   white_heavy_check_mark\nInternational Nutritio...      unknown
# 3151          nannannannan 1/5/2019] Yetunde: Very good            cy
# 3186                                     nannannannan 1"           tl
# 3389   nannannannanP   r   i   n   c   Y   o   r   kJ...           cy
# 3421    nannannannanWork Permits VisaJan 20 · 1.7K vi...           fi
# 3519                                    nannannannan 20"           fi
# 3617   nannannannanWork Permit Visa Agent & Visa Cons...           fi
# 3664   nannannannanWork Permit Visa Agent & Visa Cons...           fi
# 3740   WEB DEVELOPMENT FULL COURSE\nKhris Digital Aca...      unknown
# 3781    nannannannan/watch/?ref=search&v=754234982258...           ca
# 3874   nannannannanP   r   i   n   c   Y   o   r   kJ...           cy
# 4040                               nannannannanOPEN 479            fi
# 4359    nannannannan/texan.buddha/videos/334083218263...           sv
# 7060   Mundo Bita - Meu Pequeno Coração by Mundo Bita...           pt
# 13658  Mundo Bita - Meu Pequeno Coração by Mundo Bita...           pt

# %%
train_not_en2.shape
# Out:
# (46, 10)

# %%
train_not_en2
# Out:
#       textid                       Date Views sourcetype  \
# 582      577  2019-08-08 08:58:27+00:00     8    twitter
# 1413    1398  2019-07-23 11:01:13+00:00     0    twitter
# 1419    1404  2019-07-19 12:39:18+00:00    15    twitter
# 1461    1446  2019-06-26 04:41:45+00:00     8    twitter
# 2413    2371  2020-10-28 13:30:10+00:00     2    twitter
# 3183    3134  2020-04-02 15:47:02+00:00     0    twitter
# 6245    6107  2021-06-10 09:17:17+00:00   195    twitter
# 6247    6109  2021-06-09 23:21:49+00:00   278    twitter
# 7605    7428  2022-06-30 13:35:09+00:00     6    twitter
# 125     9102                       None     0   facebook
# 130     9103                       None     0   facebook
# 342     9244                       None     0   facebook
# 507     9403                       None  1300   facebook
# 616     9486                       None     9   facebook
# 756     9625                       None     0   facebook
# 766     9632                       None     0   facebook
# 772     9633                       None   674   facebook
# 819     9675                       None   852   facebook
# 851     9706                       None     0   facebook
# 854     9709                       None     0   facebook
# 890     9737                       None     0   facebook
# 936     9764                       None     0   facebook
# 959     9778                       None     0   facebook
# 986     9796                       None     0   facebook
# 1022    9814                       None   680   facebook
# 1155    9916                       None     0   facebook
# 1164    9917                       None    15   facebook
# 1333   10052                       None     0   facebook
# 1336   10053                       None   499   facebook
# 1564   10232                       None     0   facebook
# 2617   11040        2022-06-03 00:00:00   116   facebook
# 2787   11204        2022-09-23 00:00:00  1100   facebook
# 3151   11420        2019-01-05 00:00:00     0   facebook
# 3186   11424                       None     0   facebook
# 3389   11440                       None   170   facebook
# 3421   11461                       None  1700   facebook
# 3519   11545                       None     0   facebook
# 3617   11632                       None   369   facebook
# 3664   11671                       None  1500   facebook
# 3740   11740        2022-10-10 00:00:00   471   facebook
# 3781   11748                       None     0   facebook
# 3874   11749                       None   128   facebook
# 4040   11903                       None     0   facebook
# 4359   12158                       None     0   facebook
# 7060   18339                 2017-08-24   604    youtube
# 13658  23478                 2017-08-24   690    youtube
#
#                                                  alltext  \
# 582
# 1413   APPLY: Better Together Challenge 2019 for youn...
# 1419   Better Together Challenge 2019 for young Chang...
# 1461                         Exploring biological &amp
# 2413                                          Live &gt
# 3183             @Unathi_Kwaza I'm touched Unathi &amp
# 6245                                     #Eritrea &amp
# 6247                                    #Ethiopia &amp
# 7605                                       Social &amp
# 125                                     nannannannannan
# 130                                    nannannannan2022
# 342                               nannannannan Botswan"
# 507     nannannannanSuid Afrika South AfricaFeb 9 · 1...
# 616     nannannannanAyòdélé Adéfowópè AdébósìnMar 13,...
# 756     nannannannan over 3000 rural farmers have bee...
# 766     nannannannan/gregg.fick/videos/33966311503658...
# 772      nannannannanGregg FickMay 12, 2020 · 674 views
# 819     nannannannanZimbabweYadzoka/MayibuyeiZimbabwe...
# 851                                nannannannanOPEN 656
# 854                                nannannannanOPEN 352
# 890                       nannannannan against all odds
# 936                         nannannannan if it's true "
# 959                                    nannannannan2019
# 986                                    nannannannan re"
# 1022     nannannannanGregg FickMay 12, 2020 · 680 views
# 1155    nannannannan/sarala.rajendran/videos/37331836...
# 1164    nannannannanSarala RajendranApr 4, 2022 · 15 ...
# 1333    nannannannan/phindile.george/videos/691405748...
# 1336    nannannannanPhindile George ZibulaMar 4, 2022...
# 1564                           nannannannanBinary robot
# 2617    Group 1\nPhilippine Social Problems on Corrup...
# 2787    ✅\nInternational Nutrition Olympiad\nVideo le...
# 3151          nannannannan 1/5/2019] Yetunde: Very good
# 3186                                    nannannannan 1"
# 3389    nannannannanP   r   i   n   c   Y   o   r   k...
# 3421    nannannannanWork Permits VisaJan 20 · 1.7K vi...
# 3519                                   nannannannan 20"
# 3617    nannannannanWork Permit Visa Agent & Visa Con...
# 3664    nannannannanWork Permit Visa Agent & Visa Con...
# 3740    WEB DEVELOPMENT FULL COURSE\nKhris Digital Ac...
# 3781    nannannannan/watch/?ref=search&v=754234982258...
# 3874    nannannannanP   r   i   n   c   Y   o   r   k...
# 4040                               nannannannanOPEN 479
# 4359    nannannannan/texan.buddha/videos/334083218263...
# 7060     Mundo Bita - Meu Pequeno Coração by Mundo Bi...
# 13658    Mundo Bita - Meu Pequeno Coração by Mundo Bi...
#
#                                                 Text_emt  \
# 582
# 1413   APPLY: Better Together Challenge 2019 for youn...
# 1419   Better Together Challenge 2019 for young Chang...
# 1461                         Exploring biological &amp
# 2413                                          Live &gt
# 3183             @Unathi_Kwaza I'm touched Unathi &amp
# 6245                                     #Eritrea &amp
# 6247                                    #Ethiopia &amp
# 7605                                       Social &amp
# 125                                     nannannannannan
# 130                                    nannannannan2022
# 342                               nannannannan Botswan"
# 507     nannannannanSuid Afrika South AfricaFeb 9 · 1...
# 616     nannannannanAyòdélé Adéfowópè AdébósìnMar 13,...
# 756     nannannannan over 3000 rural farmers have bee...
# 766     nannannannan/gregg.fick/videos/33966311503658...
# 772      nannannannanGregg FickMay 12, 2020 · 674 views
# 819     nannannannanZimbabweYadzoka/MayibuyeiZimbabwe...
# 851                                nannannannanOPEN 656
# 854                                nannannannanOPEN 352
# 890                       nannannannan against all odds
# 936                         nannannannan if it's true "
# 959                                    nannannannan2019
# 986                                    nannannannan re"
# 1022     nannannannanGregg FickMay 12, 2020 · 680 views
# 1155    nannannannan/sarala.rajendran/videos/37331836...
# 1164    nannannannanSarala RajendranApr 4, 2022 · 15 ...
# 1333    nannannannan/phindile.george/videos/691405748...
# 1336    nannannannanPhindile George ZibulaMar 4, 2022...
# 1564                           nannannannanBinary robot
# 2617    Group 1\nPhilippine Social Problems on Corrup...
# 2787    ✅\nInternational Nutrition Olympiad\nVideo le...
# 3151          nannannannan 1/5/2019] Yetunde: Very good
# 3186                                    nannannannan 1"
# 3389    nannannannanP   r   i   n   c   Y   o   r   k...
# 3421    nannannannanWork Permits VisaJan 20 · 1.7K vi...
# 3519                                   nannannannan 20"
# 3617    nannannannanWork Permit Visa Agent & Visa Con...
# 3664    nannannannanWork Permit Visa Agent & Visa Con...
# 3740    WEB DEVELOPMENT FULL COURSE\nKhris Digital Ac...
# 3781    nannannannan/watch/?ref=search&v=754234982258...
# 3874    nannannannanP   r   i   n   c   Y   o   r   k...
# 4040                               nannannannanOPEN 479
# 4359    nannannannan/texan.buddha/videos/334083218263...
# 7060     Mundo Bita - Meu Pequeno Coração by Mundo Bi...
# 13658    Mundo Bita - Meu Pequeno Coração by Mundo Bi...
#
#                                                 Text_emj Text_langue  \
# 582                                                          unknown
# 1413   APPLY: Better Together Challenge 2019 for youn...          no
# 1419   Better Together Challenge 2019 for young Chang...          no
# 1461                         Exploring biological &amp            ro
# 2413                                          Live &gt            da
# 3183             @Unathi_Kwaza I'm touched Unathi &amp            sw
# 6245                                     #Eritrea &amp            ro
# 6247                                    #Ethiopia &amp            sw
# 7605                                       Social &amp            ca
# 125                                     nannannannannan           fi
# 130                                    nannannannan2022           tl
# 342                               nannannannan Botswan"           tl
# 507     nannannannanSuid Afrika South AfricaFeb 9 · 1...          af
# 616     nannannannanAyòdélé Adéfowópè AdébósìnMar 13,...          fr
# 756     nannannannan over 3000 rural farmers have bee...          no
# 766     nannannannan/gregg.fick/videos/33966311503658...          sv
# 772      nannannannanGregg FickMay 12, 2020 · 674 views           tl
# 819     nannannannanZimbabweYadzoka/MayibuyeiZimbabwe...          sw
# 851                                nannannannanOPEN 656           fi
# 854                                nannannannanOPEN 352           fi
# 890                       nannannannan against all odds           sv
# 936                         nannannannan if it's true "           fr
# 959                                    nannannannan2019           fi
# 986                                    nannannannan re"           fi
# 1022     nannannannanGregg FickMay 12, 2020 · 680 views           tl
# 1155    nannannannan/sarala.rajendran/videos/37331836...          fi
# 1164    nannannannanSarala RajendranApr 4, 2022 · 15 ...          sv
# 1333    nannannannan/phindile.george/videos/691405748...          et
# 1336    nannannannanPhindile George ZibulaMar 4, 2022...          de
# 1564                           nannannannanBinary robot           tl
# 2617    Group 1\nPhilippine Social Problems on Corrup...          ko
# 2787    white_heavy_check_mark\nInternational Nutriti...          ko
# 3151          nannannannan 1/5/2019] Yetunde: Very good           cy
# 3186                                    nannannannan 1"           tl
# 3389    nannannannanP   r   i   n   c   Y   o   r   k...          cy
# 3421    nannannannanWork Permits VisaJan 20 · 1.7K vi...          fi
# 3519                                   nannannannan 20"           fi
# 3617    nannannannanWork Permit Visa Agent & Visa Con...          fi
# 3664    nannannannanWork Permit Visa Agent & Visa Con...          fi
# 3740    WEB DEVELOPMENT FULL COURSE\nKhris Digital Ac...          ko
# 3781    nannannannan/watch/?ref=search&v=754234982258...          ca
# 3874    nannannannanP   r   i   n   c   Y   o   r   k...          cy
# 4040                               nannannannanOPEN 479           fi
# 4359    nannannannan/texan.buddha/videos/334083218263...          sv
# 7060     Mundo Bita - Meu Pequeno Coração by Mundo Bi...          pt
# 13658    Mundo Bita - Meu Pequeno Coração by Mundo Bi...          pt
#
#                                           Text_translate Text_langue2
# 582                                                           unknown
# 1413   APPLY: Better Together Challenge 2019 for youn...           no
# 1419   Better Together Challenge 2019 for young Chang...           no
# 1461                         Exploring biological &amp             ro
# 2413                                            Live &gt           da
# 3183             @Unathi_Kwaza I'm touched Unathi &amp             sw
# 6245                                     #Eritrea &amp             ro
# 6247                                    #Ethiopia &amp             sw
# 7605                                       Social &amp             ca
# 125                                         nannannannan           tl
# 130                                    nannannannan2022            fi
# 342                                nannannannan Botswan"           tl
# 507    nannannanSuid Afrika South AfricaFeb 9 · 1.3K ...           af
# 616    nannannanAyodéle Adéfópe AdébósinMar 13, 2021 ...           fr
# 756     nannannannan over 3000 rural farmers have bee...           no
# 766     nannannannan/gregg.fick/videos/3396631150365848/           sv
# 772       nannannannanGregg FickMay 12, 2020 · 674 views           tl
# 819    nannannanZimbabweYadzoka/MayibuyeiZimbabweSep ...           sw
# 851                                nannannannanOPEN 656            fi
# 854                                nannannannanOPEN 352            fi
# 890                           nannannan against all odds           cy
# 936                         nannannannan if it's true "            fr
# 959                                    nannannannan2019            fi
# 986                                        nannannan re"           tl
# 1022      nannannannanGregg FickMay 12, 2020 · 680 views           tl
# 1155   nannannannan/sarala.rajendran/videos/373318368...           fi
# 1164     nannannanSarala RajendranApr 4, 2022 · 15 views           sv
# 1333    nannannannan/phindile.george/videos/691405748...           et
# 1336   nannannanPhindile George ZibulaMar 4, 2022 · 4...           de
# 1564                           nannannannanBinary robot            tl
# 2617   Group 1\nPhilippine Social Problems on Corrupt...      unknown
# 2787   white_heavy_check_mark\nInternational Nutritio...      unknown
# 3151          nannannannan 1/5/2019] Yetunde: Very good            cy
# 3186                                     nannannannan 1"           tl
# 3389   nannannannanP   r   i   n   c   Y   o   r   kJ...           cy
# 3421    nannannannanWork Permits VisaJan 20 · 1.7K vi...           fi
# 3519                                    nannannannan 20"           fi
# 3617   nannannannanWork Permit Visa Agent & Visa Cons...           fi
# 3664   nannannannanWork Permit Visa Agent & Visa Cons...           fi
# 3740   WEB DEVELOPMENT FULL COURSE\nKhris Digital Aca...      unknown
# 3781    nannannannan/watch/?ref=search&v=754234982258...           ca
# 3874   nannannannanP   r   i   n   c   Y   o   r   kJ...           cy
# 4040                               nannannannanOPEN 479            fi
# 4359    nannannannan/texan.buddha/videos/334083218263...           sv
# 7060   Mundo Bita - Meu Pequeno Coração by Mundo Bita...           pt
# 13658  Mundo Bita - Meu Pequeno Coração by Mundo Bita...           pt

# %%
df_new3=train_not_en2['Text_langue2'].value_counts().reset_index()#.plot(kind='bar')
ax = sns.barplot(x='Text_langue2', y='index', data=df_new3)
ax.set_title('Count of records for all languages in data')
ax.set_xlabel('Languages in data')
ax.set_ylabel('Number of count')
plt.show()

# %%
train_en2.head(10)
# Out:
#      textid                       Date Views sourcetype  \
# 1139   1133  2019-11-22 07:50:43+00:00     3    twitter
# 1150   1144  2019-11-19 08:48:39+00:00    20    twitter
# 1182   1173  2019-11-04 06:30:17+00:00     6    twitter
# 1246   1237  2019-10-02 15:58:27+00:00     8    twitter
# 1275   1265  2019-09-25 08:50:56+00:00     3    twitter
# 1390   1375  2019-08-02 06:30:07+00:00     0    twitter
# 1528   1510  2019-06-04 16:43:32+00:00    20    twitter
# 1668   1646  2019-03-28 10:46:39+00:00     1    twitter
# 3447   3396  2020-10-13 08:19:01+00:00     5    twitter
# 3464   3412  2020-10-07 16:55:43+00:00    62    twitter
#
#                                                 alltext  \
# 1139  Bonjour @africatechie; je repensais Ã  votre p...
# 1150  #ECONOMÃAðŸ‡²ðŸ‡¦_x000D_\n_x000D_\nEn la reun...
# 1182  Dans le cadre de l'Africa Basque Challenge don...
# 1246  Tu as entre 18 et 45 ans ?_x000D_\n_x000D_\nTu...
# 1275  Lâ€™ESTIA co-organise une initiative dÃ©nommÃ©...
# 1390  ð—¥ð—¼ð˜€ð—¸ð—¶ð—¹ð—¹ ðŸ§—â€â™€ï¸ðŸ¤...
# 1528  .@Rebepl ha recibido esta maÃ±ana al equipo â€...
# 1668  ðŸŽ‰MaÃ¯a Africa est laurÃ©at de l'African Inn...
# 3447  JÃ³venes de Canarias y Senegal unen su talento...
# 3464  ðŸŒ Canarias y Senegal unen su talento joven ...
#
#                                                Text_emt  \
# 1139  Bonjour @africatechie; je repensais Ã  votre p...
# 1150  #ECONOMÃAðŸ‡²ðŸ‡¦_x000D_\n_x000D_\nEn la reun...
# 1182  Dans le cadre de l'Africa Basque Challenge don...
# 1246  Tu as entre 18 et 45 ans ?_x000D_\n_x000D_\nTu...
# 1275  Lâ€™ESTIA co-organise une initiative dÃ©nommÃ©...
# 1390  ð—¥ð—¼ð˜€ð—¸ð—¶ð—¹ð—¹ ðŸ§—â€â™€ï¸ðŸ¤...
# 1528  .@Rebepl ha recibido esta maÃ±ana al equipo â€...
# 1668  ðŸŽ‰MaÃ¯a Africa est laurÃ©at de l'African Inn...
# 3447  JÃ³venes de Canarias y Senegal unen su talento...
# 3464  ðŸŒ Canarias y Senegal unen su talento joven ...
#
#                                                Text_emj Text_langue  \
# 1139  Bonjour @africatechie; je repensais Ã  votre p...          fr
# 1150  #ECONOMÃAðŸ‡²ðŸ‡¦_x000D_\n_x000D_\nEn la reun...          es
# 1182  Dans le cadre de l'Africa Basque Challenge don...          fr
# 1246  Tu as entre 18 et 45 ans ?_x000D_\n_x000D_\nTu...          fr
# 1275  Lâ€trade_markESTIA co-organise une initiative ...          fr
# 1390  ð—¥ð—¼ð˜€ð—¸ð—¶ð—¹ð—¹ ðŸ§—â€âtrade_mar...          de
# 1528  .@Rebepl ha recibido esta maÃ±ana al equipo â€...          es
# 1668  ðŸŽ‰MaÃ¯a Africa est laurÃcopyrightat de l'Afr...          fr
# 3447  JÃ³venes de Canarias y Senegal unen su talento...          es
# 3464  ðŸŒ Canarias y Senegal unen su talento joven ...          es
#
#                                          Text_translate Text_langue2
# 1139  Hello @africatechie; I was thinking about your...           en
# 1150  #ECONOMÃAðŸ‡²ðŸ‡¦_x000D_\n_x000D_\nAt the meet...           en
# 1182  Within the framework of the Africa Basque Chal...           en
# 1246  Are you between 18 and 45?_x000D_\n_x000D_\nDo...           en
# 1275  Lâ€trade_markESTIA co-organizes a copyright in...           en
# 1390  ð—¥ð—¼ð˜€ð—¸ð—¶ð—¹ð—¹ ðŸ§—â€âtrade_mark€ï¸ðŸ¤ ...           en
# 1528  .@Rebepl received the â€˜Earthâ€ trade_mark te...           en
# 1668  ðŸŽ‰MaÃ¯a Africa is the winner of the @WHO Afr...           en
# 3447  Young people from the Canary Islands and Seneg...           en
# 3464  ðŸŒ The Canary Islands and Senegal unite their...           en

# %%
train_en['Text_translate']= train_en['Text_emj']
# Out:
# <ipython-input-157-dc96e9d80cf4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_en['Text_translate']= train_en['Text_emj']

# %%
#train_en
train_en2.dropna()
# Out:
#       textid                       Date Views sourcetype  \
# 1139    1133  2019-11-22 07:50:43+00:00     3    twitter
# 1150    1144  2019-11-19 08:48:39+00:00    20    twitter
# 1182    1173  2019-11-04 06:30:17+00:00     6    twitter
# 1246    1237  2019-10-02 15:58:27+00:00     8    twitter
# 1275    1265  2019-09-25 08:50:56+00:00     3    twitter
# ...      ...                        ...   ...        ...
# 16684  25978                 2017-08-24   390    youtube
# 16829  26092                 2020-08-24   228    youtube
# 16875  26122                 2023-08-22   883    youtube
# 16945  26177                 2016-08-24   692    youtube
# 17425  26538                       None    80    youtube
#
#                                                  alltext  \
# 1139   Bonjour @africatechie; je repensais Ã  votre p...
# 1150   #ECONOMÃAðŸ‡²ðŸ‡¦_x000D_\n_x000D_\nEn la reun...
# 1182   Dans le cadre de l'Africa Basque Challenge don...
# 1246   Tu as entre 18 et 45 ans ?_x000D_\n_x000D_\nTu...
# 1275   Lâ€™ESTIA co-organise une initiative dÃ©nommÃ©...
# ...                                                  ...
# 16684    Mundo Bita - Meu Pequeno Coração by Mundo Bi...
# 16829    Diversidad social y conflictos en procesos d...
# 16875    Ansou Damaro: les pays gouvernés par les sol...
# 16945    Africanistan : l’Afrique en crise va-t-elle ...
# 17425    Signal de Walf Tv coupé: Bougane apporte son...
#
#                                                 Text_emt  \
# 1139   Bonjour @africatechie; je repensais Ã  votre p...
# 1150   #ECONOMÃAðŸ‡²ðŸ‡¦_x000D_\n_x000D_\nEn la reun...
# 1182   Dans le cadre de l'Africa Basque Challenge don...
# 1246   Tu as entre 18 et 45 ans ?_x000D_\n_x000D_\nTu...
# 1275   Lâ€™ESTIA co-organise une initiative dÃ©nommÃ©...
# ...                                                  ...
# 16684    Mundo Bita - Meu Pequeno Coração by Mundo Bi...
# 16829    Diversidad social y conflictos en procesos d...
# 16875    Ansou Damaro: les pays gouvernés par les sol...
# 16945    Africanistan : l’Afrique en crise va-t-elle ...
# 17425    Signal de Walf Tv coupé: Bougane apporte son...
#
#                                                 Text_emj Text_langue  \
# 1139   Bonjour @africatechie; je repensais Ã  votre p...          fr
# 1150   #ECONOMÃAðŸ‡²ðŸ‡¦_x000D_\n_x000D_\nEn la reun...          es
# 1182   Dans le cadre de l'Africa Basque Challenge don...          fr
# 1246   Tu as entre 18 et 45 ans ?_x000D_\n_x000D_\nTu...          fr
# 1275   Lâ€trade_markESTIA co-organise une initiative ...          fr
# ...                                                  ...         ...
# 16684    Mundo Bita - Meu Pequeno Coração by Mundo Bi...          pt
# 16829    Diversidad social y conflictos en procesos d...          es
# 16875    Ansou Damaro: les pays gouvernés par les sol...          fr
# 16945    Africanistan : l’Afrique en crise va-t-elle ...          fr
# 17425    Signal de Walf Tv coupé: Bougane apporte son...          fr
#
#                                           Text_translate Text_langue2
# 1139   Hello @africatechie; I was thinking about your...           en
# 1150   #ECONOMÃAðŸ‡²ðŸ‡¦_x000D_\n_x000D_\nAt the meet...           en
# 1182   Within the framework of the Africa Basque Chal...           en
# 1246   Are you between 18 and 45?_x000D_\n_x000D_\nDo...           en
# 1275   Lâ€trade_markESTIA co-organizes a copyright in...           en
# ...                                                  ...          ...
# 16684  Mundo Bita - Meu Pequeno Coração by Mundo Bita...           en
# 16829  Social diversity and conflicts in urban transf...           en
# 16875  Ansou Damaro: countries ruled by soldiers have...           en
# 16945  Africanistan: will Africa in crisis end up in ...           en
# 17425  Walf Tv signal cut: Bougane supports Walf and ...           en
#
# [148 rows x 10 columns]

# %%
train_en.dropna()
# Out:
#       textid                       Date Views sourcetype  \
# 0          1  2019-12-19 15:30:09+00:00     0    twitter
# 1          2  2019-12-05 15:58:40+00:00    54    twitter
# 2          3  2019-12-01 14:36:11+00:00    10    twitter
# 3          4  2019-11-25 07:49:35+00:00     0    twitter
# 4          5  2019-11-21 22:00:30+00:00     4    twitter
# ...      ...                        ...   ...        ...
# 18836  27577                 2023-08-16     8    youtube
# 18837  27578                 2017-08-24   623    youtube
# 18839  27579                       None     0    youtube
# 18840  27580                       None    64    youtube
# 18842  27581                 2023-08-23    30    youtube
#
#                                                  alltext  \
# 0      CLIMATE SMART WATER GOVERNANCE SHARED ECOSYSTE...
# 1      READ: #OUTA says that; while universal health ...
# 2      policital and social issues.  You wanna worry ...
# 3      @WalesRugby South Africa has MANY social ills....
# 4      Opposition weaknesses are relevant to the bigg...
# ...                                                  ...
# 18836    World Cancer Day 2023_AFRIK-GLO HEDI by AFRI...
# 18837    Ariana Grande - Dangerous Woman (A Cappella)...
# 18839    VOICE OF AFRIKA If we don't UNITE we will ne...
# 18840    CHALLENGES THAT LEADERS FACE WHILE IN THE PO...
# 18842    Its a Zebra Spectacle in the Legendary Tsavo...
#
#                                                 Text_emt  \
# 0      CLIMATE SMART WATER GOVERNANCE SHARED ECOSYSTE...
# 1      REASadness #OUTA says that; while universal he...
# 2      policital and social issues.  You wanna worry ...
# 3      @WalesRugby South Africa has MANY social ills....
# 4      Opposition weaknesses are relevant to the bigg...
# ...                                                  ...
# 18836    World Cancer Day 2023_AFRIK-GLO HEDI by AFRI...
# 18837    Ariana Grande - Dangerous Woman (A CappellaC...
# 18839    VOICE OF AFRIKA If we don't UNITE we will ne...
# 18840    CHALLENGES THAT LEADERS FACE WHILE IN THE PO...
# 18842    Its a Zebra Spectacle in the Legendary Tsavo...
#
#                                                 Text_emj Text_langue  \
# 0      CLIMATE SMART WATER GOVERNANCE SHARED ECOSYSTE...          en
# 1      REASadness #OUTA says that; while universal he...          en
# 2      policital and social issues.  You wanna worry ...          en
# 3      @WalesRugby South Africa has MANY social ills....          en
# 4      Opposition weaknesses are relevant to the bigg...          en
# ...                                                  ...         ...
# 18836    World Cancer Day 2023_AFRIK-GLO HEDI by AFRI...          en
# 18837    Ariana Grande - Dangerous Woman (A CappellaC...          en
# 18839    VOICE OF AFRIKA If we don't UNITE we will ne...          en
# 18840    CHALLENGES THAT LEADERS FACE WHILE IN THE PO...          en
# 18842    Its a Zebra Spectacle in the Legendary Tsavo...          en
#
#                                           Text_translate
# 0      CLIMATE SMART WATER GOVERNANCE SHARED ECOSYSTE...
# 1      REASadness #OUTA says that; while universal he...
# 2      policital and social issues.  You wanna worry ...
# 3      @WalesRugby South Africa has MANY social ills....
# 4      Opposition weaknesses are relevant to the bigg...
# ...                                                  ...
# 18836    World Cancer Day 2023_AFRIK-GLO HEDI by AFRI...
# 18837    Ariana Grande - Dangerous Woman (A CappellaC...
# 18839    VOICE OF AFRIKA If we don't UNITE we will ne...
# 18840    CHALLENGES THAT LEADERS FACE WHILE IN THE PO...
# 18842    Its a Zebra Spectacle in the Legendary Tsavo...
#
# [27387 rows x 9 columns]

# %%
train_en2.isna().head()
# Out:
#       textid   Date  Views  sourcetype  alltext  Text_emt  Text_emj  \
# 1139   False  False  False       False    False     False     False
# 1150   False  False  False       False    False     False     False
# 1182   False  False  False       False    False     False     False
# 1246   False  False  False       False    False     False     False
# 1275   False  False  False       False    False     False     False
#
#       Text_langue  Text_translate  Text_langue2
# 1139        False           False         False
# 1150        False           False         False
# 1182        False           False         False
# 1246        False           False         False
# 1275        False           False         False

# %%
# train_not_en.isna().head()
train_en['Text_langue2']= train_en['Text_langue']
# Out:
# <ipython-input-161-5949c773cae7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_en['Text_langue2']= train_en['Text_langue']

# %%
#train_not_en
#df.head(10)
shuffledlw = train_not_en.sample(frac=1)
shuffledlw.head(10)
# Out:
#       textid                       Date Views sourcetype  \
# 16829  26092                 2020-08-24   228    youtube
# 1246    1237  2019-10-02 15:58:27+00:00     8    twitter
# 2094   14313                 2023-08-22   115    youtube
# 4695    4594  2020-04-10 11:27:30+00:00     2    twitter
# 5342   16858                       None   977    youtube
# 936     9764                       None     0   facebook
# 4182   15927                       None    79    youtube
# 12737  22614                       None   454    youtube
# 8828    8621  2022-02-18 16:58:53+00:00     0    twitter
# 890     9737                       None     0   facebook
#
#                                                  alltext  \
# 16829    Diversidad social y conflictos en procesos d...
# 1246   Tu as entre 18 et 45 ans ?_x000D_\n_x000D_\nTu...
# 2094     EP1 ➡️ La ville vue par les citoyens africai...
# 4695   Il est des hommes dont la grandeur s'admir en ...
# 5342     Le Sénégal au sommet du football africain - ...
# 936                         nannannannan if it's true "
# 4182     L'appel à l'aide des réfugiés somaliens de r...
# 12737    L'équipe de Diomet révele les contre vérités...
# 8828   kinginang kagrupo yan phil. social issues nga ...
# 890                       nannannannan against all odds
#
#                                                 Text_emt  \
# 16829    Diversidad social y conflictos en procesos d...
# 1246   Tu as entre 18 et 45 ans ?_x000D_\n_x000D_\nTu...
# 2094     EP1 ➡️ La ville vue par les citoyens africai...
# 4695   Il est des hommes dont la grandeur s'admir en ...
# 5342     Le Sénégal au sommet du football africain - ...
# 936                         nannannannan if it's true "
# 4182     L'appel à l'aide des réfugiés somaliens de r...
# 12737    L'équipe de Diomet révele les contre vérités...
# 8828   kinginang kagrupo yan phil. social issues nga ...
# 890                       nannannannan against all odds
#
#                                                 Text_emj Text_langue  \
# 16829    Diversidad social y conflictos en procesos d...          es
# 1246   Tu as entre 18 et 45 ans ?_x000D_\n_x000D_\nTu...          fr
# 2094     EP1 right_arrow️ La ville vue par les citoye...          fr
# 4695   Il est des hommes dont la grandeur s'admir en ...          fr
# 5342     Le Sénégal au sommet du football africain - ...          fr
# 936                         nannannannan if it's true "           fr
# 4182     L'appel à l'aide des réfugiés somaliens de r...          fr
# 12737    L'équipe de Diomet révele les contre vérités...          fr
# 8828   kinginang kagrupo yan phil. social issues nga ...          tl
# 890                       nannannannan against all odds           sv
#
#                                           Text_translate Text_langue2
# 16829  Social diversity and conflicts in urban transf...           en
# 1246   Are you between 18 and 45?_x000D_\n_x000D_\nDo...           en
# 2094   EP1 right_arrow️ The city seen by African citi...           en
# 4695   There are men whose greatness is admired in a ...           en
# 5342   Senegal at the top of African football - #CHAN...           en
# 936                         nannannannan if it's true "            fr
# 4182   The call for help from Somali refugees returni...           en
# 12737  The Diomet team reveals the untruths of Presid...           en
# 8828   that's a brilliant groupmate, phil. The subjec...           en
# 890                           nannannan against all odds           cy

# %%
df2111 = pd.concat([train_en, train_not_en])

# %%
df2111.head(10)
# Out:
#   textid                       Date Views sourcetype  \
# 0      1  2019-12-19 15:30:09+00:00     0    twitter
# 1      2  2019-12-05 15:58:40+00:00    54    twitter
# 2      3  2019-12-01 14:36:11+00:00    10    twitter
# 3      4  2019-11-25 07:49:35+00:00     0    twitter
# 4      5  2019-11-21 22:00:30+00:00     4    twitter
# 5      6  2019-11-18 10:17:15+00:00     2    twitter
# 6      7  2019-11-12 16:08:48+00:00     0    twitter
# 7      8  2019-11-05 16:26:24+00:00     0    twitter
# 8      9  2019-10-31 15:09:28+00:00     2    twitter
# 9     10  2019-10-24 07:23:50+00:00    23    twitter
#
#                                              alltext  \
# 0  CLIMATE SMART WATER GOVERNANCE SHARED ECOSYSTE...
# 1  READ: #OUTA says that; while universal health ...
# 2  policital and social issues.  You wanna worry ...
# 3  @WalesRugby South Africa has MANY social ills....
# 4  Opposition weaknesses are relevant to the bigg...
# 5  @vcmcguire Yes; I know someone in South Africa...
# 6  @chuks_okereke A huge concern for social susta...
# 7  @SitshelaN @misazimbabwe @SANGONeT @OSISA And ...
# 8  @ebohinson The professor is this interview mak...
# 9  Malawi National Council of Sports has expresse...
#
#                                             Text_emt  \
# 0  CLIMATE SMART WATER GOVERNANCE SHARED ECOSYSTE...
# 1  REASadness #OUTA says that; while universal he...
# 2  policital and social issues.  You wanna worry ...
# 3  @WalesRugby South Africa has MANY social ills....
# 4  Opposition weaknesses are relevant to the bigg...
# 5  @vcmcguire Yes; I know someone in South Africa...
# 6  @chuks_okereke A huge concern for social susta...
# 7  @SitshelaN @misazimbabwe @SANGONeT @OSISA And ...
# 8  @ebohinson The professor is this interview mak...
# 9  Malawi National Council of Sports has expresse...
#
#                                             Text_emj Text_langue  \
# 0  CLIMATE SMART WATER GOVERNANCE SHARED ECOSYSTE...          en
# 1  REASadness #OUTA says that; while universal he...          en
# 2  policital and social issues.  You wanna worry ...          en
# 3  @WalesRugby South Africa has MANY social ills....          en
# 4  Opposition weaknesses are relevant to the bigg...          en
# 5  @vcmcguire Yes; I know someone in South Africa...          en
# 6  @chuks_okereke A huge concern for social susta...          en
# 7  @SitshelaN @misazimbabwe @SANGONeT @OSISA And ...          en
# 8  @ebohinson The professor is this interview mak...          en
# 9  Malawi National Council of Sports has expresse...          en
#
#                                       Text_translate Text_langue2
# 0  CLIMATE SMART WATER GOVERNANCE SHARED ECOSYSTE...           en
# 1  REASadness #OUTA says that; while universal he...           en
# 2  policital and social issues.  You wanna worry ...           en
# 3  @WalesRugby South Africa has MANY social ills....           en
# 4  Opposition weaknesses are relevant to the bigg...           en
# 5  @vcmcguire Yes; I know someone in South Africa...           en
# 6  @chuks_okereke A huge concern for social susta...           en
# 7  @SitshelaN @misazimbabwe @SANGONeT @OSISA And ...           en
# 8  @ebohinson The professor is this interview mak...           en
# 9  Malawi National Council of Sports has expresse...           en

# %%
df2111.columns
# Out:
# Index(['textid', 'Date', 'Views', 'sourcetype', 'alltext', 'Text_emt',
#        'Text_emj', 'Text_langue', 'Text_translate', 'Text_langue2'],
#       dtype='object')

# %%
df_new21=df2111['Text_langue2'].value_counts().reset_index()#.plot(kind='bar')
ax = sns.barplot(x='Text_langue2', y='index', data=df_new21)
ax.set_title('Count of records for all languages in data')
ax.set_xlabel('Languages in data')
ax.set_ylabel('Number of count')
plt.show()

# %%
# df2111.to_csv("D:/senego/dataafrica/oldfiles/socialdatanewclean2.csv", encoding = "UTF-8")
df2111.to_csv('/content/drive/MyDrive/Colab Notebooks/newfacebook_df2.csv')
# df=pd.read_csv("D:/senego/dataafrica/oldfiles/socialdatanewclean.csv", encoding = "UTF-8")
#df = pd.read_csv('C:/Users/Administrator/OneDrive/Documents/africa/dataafrica/socialdatanew.csv', encoding = "UTF-8")

# %%
df=df2111.copy()
df=df.astype(str)
df.head()
# Out:
#   textid                       Date Views sourcetype  \
# 0      1  2019-12-19 15:30:09+00:00     0    twitter
# 1      2  2019-12-05 15:58:40+00:00    54    twitter
# 2      3  2019-12-01 14:36:11+00:00    10    twitter
# 3      4  2019-11-25 07:49:35+00:00     0    twitter
# 4      5  2019-11-21 22:00:30+00:00     4    twitter
#
#                                              alltext  \
# 0  CLIMATE SMART WATER GOVERNANCE SHARED ECOSYSTE...
# 1  READ: #OUTA says that; while universal health ...
# 2  policital and social issues.  You wanna worry ...
# 3  @WalesRugby South Africa has MANY social ills....
# 4  Opposition weaknesses are relevant to the bigg...
#
#                                             Text_emt  \
# 0  CLIMATE SMART WATER GOVERNANCE SHARED ECOSYSTE...
# 1  REASadness #OUTA says that; while universal he...
# 2  policital and social issues.  You wanna worry ...
# 3  @WalesRugby South Africa has MANY social ills....
# 4  Opposition weaknesses are relevant to the bigg...
#
#                                             Text_emj Text_langue  \
# 0  CLIMATE SMART WATER GOVERNANCE SHARED ECOSYSTE...          en
# 1  REASadness #OUTA says that; while universal he...          en
# 2  policital and social issues.  You wanna worry ...          en
# 3  @WalesRugby South Africa has MANY social ills....          en
# 4  Opposition weaknesses are relevant to the bigg...          en
#
#                                       Text_translate Text_langue2
# 0  CLIMATE SMART WATER GOVERNANCE SHARED ECOSYSTE...           en
# 1  REASadness #OUTA says that; while universal he...           en
# 2  policital and social issues.  You wanna worry ...           en
# 3  @WalesRugby South Africa has MANY social ills....           en
# 4  Opposition weaknesses are relevant to the bigg...           en

# %%
# df=df.astype(str)

# %%
# Converting all the characters in a text into lower case
def casefoldingText(text):
    text = text.lower()
    return text
#df['Text_lower'] = df['Text_translate'].astype(str)
df['Text_lower'] = df['Text_translate'].apply(casefoldingText)
df['Text_lower'].head()
# Out:
# 0    climate smart water governance shared ecosyste...
# 1    reasadness #outa says that; while universal he...
# 2    policital and social issues.  you wanna worry ...
# 3    @walesrugby south africa has many social ills....
# 4    opposition weaknesses are relevant to the bigg...
# Name: Text_lower, dtype: object

# %%
#df.head(10)
shuffledlw = df.sample(frac=1)
shuffledlw.head(10)
# Out:
#       textid                       Date Views sourcetype  \
# 7271    7095  2022-10-31 23:42:13+00:00     2    twitter
# 2450   14585                 2023-05-24   644    youtube
# 1962    1935  2019-10-21 11:01:00+00:00     1    twitter
# 13016  22879                 2023-08-18   283    youtube
# 1037    1032  2019-04-09 06:32:43+00:00     2    twitter
# 14205  23942                 2023-08-18   425    youtube
# 3786   15657                 2020-08-24   422    youtube
# 2917   14962                 2017-08-24   546    youtube
# 2741   14822                 2021-08-24   741    youtube
# 4832    4725  2021-09-28 01:05:28+00:00     1    twitter
#
#                                                  alltext  \
# 7271   @TheBigCatPeople The problem lies within the s...
# 2450     Social media and political polarization in A...
# 1962   #RainbowScars confronts many of the questions ...
# 13016    6 फ़रवरी 2023 Political Science Answer Key। B...
# 1037   Lord Naaba is one of theTop most powerful spir...
# 14205    Kimberlé Crenshaw on Critical Race Theory, I...
# 3786     Hair Love | Oscar®-Winning Short Film (Full)...
# 2917     Dierks Bentley - Somewhere On A Beach (Offic...
# 2741     Mama Africa (Peter Tosh) feat. Andrew Tosh |...
# 4832   It will look across the seas and see individua...
#
#                                                 Text_emt  \
# 7271   @TheBigCatPeople The problem lies within the s...
# 2450     Social media and political polarization in A...
# 1962   #RainbowScars confronts many of the questions ...
# 13016    6 फ़रवरी 2023 Political Science Answer Key। B...
# 1037   Lord Naaba is one of theTop most powerful spir...
# 14205    Kimberlé Crenshaw on Critical Race Theory, I...
# 3786     Hair Love | Oscar®-Winning Short Film (FullC...
# 2917     Dierks Bentley - Somewhere On A Beach (Offic...
# 2741     Mama Africa (Peter ToshConfusion feat. Andre...
# 4832   It will look across the seas and see individua...
#
#                                                 Text_emj Text_langue  \
# 7271   @TheBigCatPeople The problem lies within the s...          en
# 2450     Social media and political polarization in A...          en
# 1962   #RainbowScars confronts many of the questions ...          en
# 13016    6 फ़रवरी 2023 Political Science Answer Key। B...          en
# 1037   Lord Naaba is one of theTop most powerful spir...          en
# 14205    Kimberlé Crenshaw on Critical Race Theory, I...          en
# 3786     Hair Love | Oscarregistered-Winning Short Fi...          en
# 2917     Dierks Bentley - Somewhere On A Beach (Offic...          en
# 2741     Mama Africa (Peter ToshConfusion feat. Andre...          en
# 4832   It will look across the seas and see individua...          en
#
#                                           Text_translate Text_langue2  \
# 7271   @TheBigCatPeople The problem lies within the s...           en
# 2450     Social media and political polarization in A...           en
# 1962   #RainbowScars confronts many of the questions ...           en
# 13016    6 फ़रवरी 2023 Political Science Answer Key। B...           en
# 1037   Lord Naaba is one of theTop most powerful spir...           en
# 14205    Kimberlé Crenshaw on Critical Race Theory, I...           en
# 3786     Hair Love | Oscarregistered-Winning Short Fi...           en
# 2917     Dierks Bentley - Somewhere On A Beach (Offic...           en
# 2741     Mama Africa (Peter ToshConfusion feat. Andre...           en
# 4832   It will look across the seas and see individua...           en
#
#                                               Text_lower
# 7271   @thebigcatpeople the problem lies within the s...
# 2450     social media and political polarization in a...
# 1962   #rainbowscars confronts many of the questions ...
# 13016    6 फ़रवरी 2023 political science answer key। b...
# 1037   lord naaba is one of thetop most powerful spir...
# 14205    kimberlé crenshaw on critical race theory, i...
# 3786     hair love | oscarregistered-winning short fi...
# 2917     dierks bentley - somewhere on a beach (offic...
# 2741     mama africa (peter toshconfusion feat. andre...
# 4832   it will look across the seas and see individua...

# %%
#df = shuffledlw.copy()

# %%
# Remove unwanted characters
import string
def cleaningText(text):
    text = re.sub(r'@[A-Za-z0-9]+', '', text) # remove mentions
    text = re.sub(r'#[A-Za-z0-9]+', '', text) # remove hashtag
    text = re.sub(r'RT[\s]', '', text) # remove RT
    text = re.sub(r"http\S+", '', text) # remove link
    text = re.sub(r"[!@#$]", '', text) # remove link
    text = re.sub(r'[0-9]+', '', text) # remove numbers
    text = re.sub(r'[^\x00-\x7f]', "", text) # non ASCII characters

    text = text.replace('\n', ' ')# replace new line into space
    text = text.translate(str.maketrans('', '', string.punctuation)) # remove all punctuations
    text = text.strip(' ') # remove characters space from both left and right text
    return text
df['Text_punct'] = df['Text_lower'].astype(str)
df['Text_punct'] = df['Text_lower'].apply(cleaningText)
df['Text_punct'].head()
# Out:
# 0    climate smart water governance shared ecosyste...
# 1    reasadness  says that while universal health c...
# 2    policital and social issues  you wanna worry f...
# 3    south africa has many social illsxd drugs and ...
# 4    opposition weaknesses are relevant to the bigg...
# Name: Text_punct, dtype: object

# %%
df.columns
# Out:
# Index(['textid', 'Date', 'Views', 'sourcetype', 'alltext', 'Text_emt',
#        'Text_emj', 'Text_langue', 'Text_translate', 'Text_langue2',
#        'Text_lower', 'Text_punct'],
#       dtype='object')

# %%
df_show=df[['textid', 'alltext', 'sourcetype','Text_translate', 'Text_lower',
       'Text_punct']]
df_show=df_show.sample(frac=1)
df_show.head(10)
# Out:
#       textid                                            alltext sourcetype  \
# 3016    2968  Africa (Namibia; Botswana; Kenya; Tanzania) is...    twitter
# 7155   18428    Six Nations Round 1 with Greig Laidlaw by Th...    youtube
# 8343    8153  Apply for the ChangeMakers Innovation Challeng...    twitter
# 5254   16783    Watch A Minute-To-Minute Breakdown Leading U...    youtube
# 17528  26599    Social Phobia vs Social Anxiety Disorder (Ne...    youtube
# 3052   15053    Africa's 'Decade of Progress' is under threa...    youtube
# 2483   14608    IHA Social Impact Webinar - August 2022 Edit...    youtube
# 3972    3907  Truth be told...social distancing was and is a...    twitter
# 9787   20493    Emerging issues | Civic Education | SS3 | 1s...    youtube
# 2824    2777  Good morning.\n\nGlobal Philanthropy Alliance ...    twitter
#
#                                           Text_translate  \
# 3016   Africa (Namibia; Botswana; Kenya; TanzaniaConf...
# 7155     Six Nations Round 1 with Greig Laidlaw by Th...
# 8343   Apply for the ChangeMakers Innovation Challeng...
# 5254     Watch A Minute-To-Minute Breakdown Leading U...
# 17528    Social Phobia vs Social Anxiety Disorder (Ne...
# 3052     Africa's 'Decade of Progress' is under threa...
# 2483     IHA Social Impact Webinar - August 2022 Edit...
# 3972   Truth be told...social distancing was and is a...
# 9787     Emerging issues | Civic Education | SS3 | 1s...
# 2824   Good morning.\n\nGlobal Philanthropy Alliance ...
#
#                                               Text_lower  \
# 3016   africa (namibia; botswana; kenya; tanzaniaconf...
# 7155     six nations round 1 with greig laidlaw by th...
# 8343   apply for the changemakers innovation challeng...
# 5254     watch a minute-to-minute breakdown leading u...
# 17528    social phobia vs social anxiety disorder (ne...
# 3052     africa's 'decade of progress' is under threa...
# 2483     iha social impact webinar - august 2022 edit...
# 3972   truth be told...social distancing was and is a...
# 9787     emerging issues | civic education | ss3 | 1s...
# 2824   good morning.\n\nglobal philanthropy alliance ...
#
#                                               Text_punct
# 3016   africa namibia botswana kenya tanzaniaconfusio...
# 7155   six nations round  with greig laidlaw by the g...
# 8343   apply for the changemakers innovation challeng...
# 5254   watch a minutetominute breakdown leading up to...
# 17528  social phobia vs social anxiety disorder new r...
# 3052   africas decade of progress is under threat  ib...
# 2483   iha social impact webinar  august  edition by ...
# 3972   truth be toldsocial distancing was and is a ch...
# 9787   emerging issues  civic education  ss  st term ...
# 2824   good morning  global philanthropy alliance is ...

# %%
df.head(2)
# Out:
#   textid                       Date Views sourcetype  \
# 0      1  2019-12-19 15:30:09+00:00     0    twitter
# 1      2  2019-12-05 15:58:40+00:00    54    twitter
#
#                                              alltext  \
# 0  CLIMATE SMART WATER GOVERNANCE SHARED ECOSYSTE...
# 1  READ: #OUTA says that; while universal health ...
#
#                                             Text_emt  \
# 0  CLIMATE SMART WATER GOVERNANCE SHARED ECOSYSTE...
# 1  REASadness #OUTA says that; while universal he...
#
#                                             Text_emj Text_langue  \
# 0  CLIMATE SMART WATER GOVERNANCE SHARED ECOSYSTE...          en
# 1  REASadness #OUTA says that; while universal he...          en
#
#                                       Text_translate Text_langue2  \
# 0  CLIMATE SMART WATER GOVERNANCE SHARED ECOSYSTE...           en
# 1  REASadness #OUTA says that; while universal he...           en
#
#                                           Text_lower  \
# 0  climate smart water governance shared ecosyste...
# 1  reasadness #outa says that; while universal he...
#
#                                           Text_punct
# 0  climate smart water governance shared ecosyste...
# 1  reasadness  says that while universal health c...

# %%
# Remove HTML/XML tags
from bs4 import BeautifulSoup
import html as ihtml
def html(text):
    return BeautifulSoup(text, "lxml").text
df['Text_tags'] = df['Text_punct'].astype(str)
df['Text_tags'] = df['Text_punct'].apply(html)
df['Text_tags'].head()
# Out:
# 0    climate smart water governance shared ecosyste...
# 1    reasadness  says that while universal health c...
# 2    policital and social issues  you wanna worry f...
# 3    south africa has many social illsxd drugs and ...
# 4    opposition weaknesses are relevant to the bigg...
# Name: Text_tags, dtype: object

# %% [markdown]
# ## Normalization of data

# %% [markdown]
# Chat Words Conversion
#
# This is an important text preprocessing step if we are dealing with chat data. People do use a lot of abbreviated words in chat and so it might be helpful to expand those words for our analysis purposes.
#
# Got a good list of chat slang words from this repo. We can use this for our conversion here. We can add more words to this list.

# %%
chat_words_str = """
AFAIK=As Far As I Know
AFK=Away From Keyboard
ASAP=As Soon As Possible
ATK=At The Keyboard
ATM=At The Moment
A3=Anytime, Anywhere, Anyplace
BAK=Back At Keyboard
BBL=Be Back Later
BBS=Be Back Soon
BFN=Bye For Now
B4N=Bye For Now
BRB=Be Right Back
BRT=Be Right There
BTW=By The Way
B4=Before
B4N=Bye For Now
CU=See You
CUL8R=See You Later
CYA=See You
FAQ=Frequently Asked Questions
FC=Fingers Crossed
FWIW=For What It's Worth
FYI=For Your Information
GAL=Get A Life
GG=Good Game
GN=Good Night
GMTA=Great Minds Think Alike
GR8=Great!
G9=Genius
IC=I See
ICQ=I Seek you (also a chat program)
ILU=ILU: I Love You
IMHO=In My Honest/Humble Opinion
IMO=In My Opinion
IOW=In Other Words
IRL=In Real Life
KISS=Keep It Simple, Stupid
LDR=Long Distance Relationship
LMAO=Laugh My A.. Off
LOL=Laughing Out Loud
LTNS=Long Time No See
L8R=Later
MTE=My Thoughts Exactly
M8=Mate
NRN=No Reply Necessary
OIC=Oh I See
PITA=Pain In The A..
PRT=Party
PRW=Parents Are Watching
ROFL=Rolling On The Floor Laughing
ROFLOL=Rolling On The Floor Laughing Out Loud
ROTFLMAO=Rolling On The Floor Laughing My A.. Off
SK8=Skate
STATS=Your sex and age
ASL=Age, Sex, Location
THX=Thank You
TTFN=Ta-Ta For Now!
TTYL=Talk To You Later
U=You
U2=You Too
U4E=Yours For Ever
WB=Welcome Back
WTF=What The F...
WTG=Way To Go!
WUF=Where Are You From?
W8=Wait...
7K=Sick:-D Laugher
"""

# %%
#Convert short form words
chat_words_map_dict = {}
chat_words_list = []
for line in chat_words_str.split("\n"):
    if line != "":
        cw = line.split("=")[0]
        cw_expanded = line.split("=")[1]
        chat_words_list.append(cw)
        chat_words_map_dict[cw] = cw_expanded
chat_words_list = set(chat_words_list)

def chat_words_conversion(text):
    new_text = []
    for w in text.split():
        if w.upper() in chat_words_list:
            new_text.append(chat_words_map_dict[w.upper()])
        else:
            new_text.append(w)
    return " ".join(new_text)

df['Text_chat'] = df['Text_tags'].astype(str)
df['Text_chat'] = df['Text_tags'].apply(chat_words_conversion)
df['Text_chat'].head()
# Out:
# 0    climate smart water governance shared ecosyste...
# 1    reasadness says that while universal health co...
# 2    policital and social issues you wanna worry fo...
# 3    south africa has many social illsxd drugs and ...
# 4    opposition weaknesses are relevant to the bigg...
# Name: Text_chat, dtype: object

# %% [markdown]
# Spelling Correction
#
# One another important text preprocessing step is spelling correction. Typos are common in text data and we might want to correct those spelling mistakes before we do our analysis.
#
# If we are interested in wrinting a spell corrector of our own, we can probably start with famous code from Peter Norvig.
#
# In this notebook, let us use the python package pyspellchecker for our spelling correction.

# %%
# df.to_csv("D:/senego/dataafrica/oldfiles/socialdatanewclean2chats.csv", encoding = "UTF-8")
# df=pd.read_csv("D:/senego/dataafrica/oldfiles/socialdatanewclean2chats.csv", encoding = "UTF-8")
# df=df.astype(str)
# df.head(5)

# %%
# !pip install pyspellchecker
# Out:
# Collecting pyspellchecker
#   Downloading pyspellchecker-0.7.2-py3-none-any.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 20.7 MB/s eta 0:00:00
# Installing collected packages: pyspellchecker
# Successfully installed pyspellchecker-0.7.2

# %%
# Correct spellings
import pandas as pd
from spellchecker import SpellChecker

spell = SpellChecker()

def correct_spelling(word):
    corrected_word = spell.correction(word)
    if corrected_word is not None:
        return corrected_word
    else:
        return word


df['Text_spell'] = df['Text_chat'].astype(str)
df['Text_spell'] = df['Text_chat'].apply(correct_spelling)
df['Text_spell'].head()
# Out:
# 0    climate smart water governance shared ecosyste...
# 1    reasadness says that while universal health co...
# 2    policital and social issues you wanna worry fo...
# 3    south africa has many social illsxd drugs and ...
# 4    opposition weaknesses are relevant to the bigg...
# Name: Text_spell, dtype: object

# %%
textdf2=df

# %%
train_en3 = textdf2[textdf2['Text_langue2'] == 'en']
train_not_en3 = textdf2[textdf2['Text_langue2'] != 'en']

# %%
# Translating text not in English
from deep_translator import GoogleTranslator
import langid
len_data = len( train_not_en3)
# For each article, we detect its language; if it's not English,
# we ask Google Translate to translate it into English, otherwise we keep the source text
gt = GoogleTranslator(source='auto', target='en')
max_art_len = 1000  # Here, we truncate the content to first 1000 characters; Google Translate accepts texts
                    # not longer than 5000 characters, but the volume of 1000 can be enough for classification
                    # and enables us to reduce the time of working with translation service

translated_arts = []

for i in range(len( train_not_en3)):
    if i % 200 == 0:
        print(f"Translated {i} / {len_data}")
    cur_art =  train_not_en3.iloc[i]['Text_spell'][:max_art_len]
    translated_arts.append(cur_art if langid.classify(cur_art)[0] == 'en' else gt.translate(cur_art))

train_not_en3['Text_translate2'] = translated_arts
# Out:
# Translated 0 / 46
# <ipython-input-186-d2fbf10e0604>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_not_en3['Text_translate2'] = translated_arts

# %%
# Detect and convert languages
from langdetect import detect
def detect_my(text):
   try:
       return detect(text)
   except:
       return 'unknown'
train_not_en3['Text_langue3'] = train_not_en3['Text_translate2'].apply(detect_my)
train_not_en3['Text_langue3'].head(2)
# Out:
# <ipython-input-187-f519317946ae>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_not_en3['Text_langue3'] = train_not_en3['Text_translate2'].apply(detect_my)
# 582     af
# 1413    en
# Name: Text_langue3, dtype: object

# %%
df_new2=train_not_en3['Text_langue3'].value_counts().reset_index()#.plot(kind='bar')
ax = sns.barplot(x='Text_langue3', y='index', data=df_new2)
ax.set_title('Count of records for all languages in data')
ax.set_xlabel('Languages in data')
ax.set_ylabel('Number of count')
plt.show()

# %%
train_not_en3.columns
# Out:
# Index(['textid', 'Date', 'Views', 'sourcetype', 'alltext', 'Text_emt',
#        'Text_emj', 'Text_langue', 'Text_translate', 'Text_langue2',
#        'Text_lower', 'Text_punct', 'Text_tags', 'Text_chat', 'Text_spell',
#        'Text_translate2', 'Text_langue3'],
#       dtype='object')

# %%
train_en3.columns
# Out:
# Index(['textid', 'Date', 'Views', 'sourcetype', 'alltext', 'Text_emt',
#        'Text_emj', 'Text_langue', 'Text_translate', 'Text_langue2',
#        'Text_lower', 'Text_punct', 'Text_tags', 'Text_chat', 'Text_spell'],
#       dtype='object')

# %%
train_en32 = train_not_en3[train_not_en3['Text_langue3'] == 'en']
train_not_en32 = train_not_en3[train_not_en3['Text_langue3'] != 'en']

# %%
train_not_en32.shape
# Out:
# (36, 17)

# %%
train_en32.dropna()
# Out:
#       textid                       Date Views sourcetype  \
# 1413    1398  2019-07-23 11:01:13+00:00     0    twitter
# 1419    1404  2019-07-19 12:39:18+00:00    15    twitter
# 3183    3134  2020-04-02 15:47:02+00:00     0    twitter
# 986     9796                       None     0   facebook
# 2617   11040        2022-06-03 00:00:00   116   facebook
# 2787   11204        2022-09-23 00:00:00  1100   facebook
# 3740   11740        2022-10-10 00:00:00   471   facebook
# 3781   11748                       None     0   facebook
# 7060   18339                 2017-08-24   604    youtube
# 13658  23478                 2017-08-24   690    youtube
#
#                                                  alltext  \
# 1413   APPLY: Better Together Challenge 2019 for youn...
# 1419   Better Together Challenge 2019 for young Chang...
# 3183             @Unathi_Kwaza I'm touched Unathi &amp
# 986                                    nannannannan re"
# 2617    Group 1\nPhilippine Social Problems on Corrup...
# 2787    ✅\nInternational Nutrition Olympiad\nVideo le...
# 3740    WEB DEVELOPMENT FULL COURSE\nKhris Digital Ac...
# 3781    nannannannan/watch/?ref=search&v=754234982258...
# 7060     Mundo Bita - Meu Pequeno Coração by Mundo Bi...
# 13658    Mundo Bita - Meu Pequeno Coração by Mundo Bi...
#
#                                                 Text_emt  \
# 1413   APPLY: Better Together Challenge 2019 for youn...
# 1419   Better Together Challenge 2019 for young Chang...
# 3183             @Unathi_Kwaza I'm touched Unathi &amp
# 986                                    nannannannan re"
# 2617    Group 1\nPhilippine Social Problems on Corrup...
# 2787    ✅\nInternational Nutrition Olympiad\nVideo le...
# 3740    WEB DEVELOPMENT FULL COURSE\nKhris Digital Ac...
# 3781    nannannannan/watch/?ref=search&v=754234982258...
# 7060     Mundo Bita - Meu Pequeno Coração by Mundo Bi...
# 13658    Mundo Bita - Meu Pequeno Coração by Mundo Bi...
#
#                                                 Text_emj Text_langue  \
# 1413   APPLY: Better Together Challenge 2019 for youn...          no
# 1419   Better Together Challenge 2019 for young Chang...          no
# 3183             @Unathi_Kwaza I'm touched Unathi &amp            sw
# 986                                    nannannannan re"           fi
# 2617    Group 1\nPhilippine Social Problems on Corrup...          ko
# 2787    white_heavy_check_mark\nInternational Nutriti...          ko
# 3740    WEB DEVELOPMENT FULL COURSE\nKhris Digital Ac...          ko
# 3781    nannannannan/watch/?ref=search&v=754234982258...          ca
# 7060     Mundo Bita - Meu Pequeno Coração by Mundo Bi...          pt
# 13658    Mundo Bita - Meu Pequeno Coração by Mundo Bi...          pt
#
#                                           Text_translate Text_langue2  \
# 1413   APPLY: Better Together Challenge 2019 for youn...           no
# 1419   Better Together Challenge 2019 for young Chang...           no
# 3183             @Unathi_Kwaza I'm touched Unathi &amp             sw
# 986                                        nannannan re"           tl
# 2617   Group 1\nPhilippine Social Problems on Corrupt...      unknown
# 2787   white_heavy_check_mark\nInternational Nutritio...      unknown
# 3740   WEB DEVELOPMENT FULL COURSE\nKhris Digital Aca...      unknown
# 3781    nannannannan/watch/?ref=search&v=754234982258...           ca
# 7060   Mundo Bita - Meu Pequeno Coração by Mundo Bita...           pt
# 13658  Mundo Bita - Meu Pequeno Coração by Mundo Bita...           pt
#
#                                               Text_lower  \
# 1413   apply: better together challenge 2019 for youn...
# 1419   better together challenge 2019 for young chang...
# 3183             @unathi_kwaza i'm touched unathi &amp
# 986                                        nannannan re"
# 2617   group 1\nphilippine social problems on corrupt...
# 2787   white_heavy_check_mark\ninternational nutritio...
# 3740   web development full course\nkhris digital aca...
# 3781    nannannannan/watch/?ref=search&v=754234982258...
# 7060   mundo bita - meu pequeno coração by mundo bita...
# 13658  mundo bita - meu pequeno coração by mundo bita...
#
#                                               Text_punct  \
# 1413   apply better together challenge  for young cha...
# 1419   better together challenge  for young changemak...
# 3183                         kwaza im touched unathi amp
# 986                                         nannannan re
# 2617   group  philippine social problems on corruptio...
# 2787   whiteheavycheckmark international nutrition ol...
# 3740   web development full course khris digital acad...
# 3781   nannannannanwatchrefsearchvexternallogidbcaaea...
# 7060   mundo bita  meu pequeno corao by mundo bita  y...
# 13658  mundo bita  meu pequeno corao by mundo bita  y...
#
#                                                Text_tags  \
# 1413   apply better together challenge  for young cha...
# 1419   better together challenge  for young changemak...
# 3183                         kwaza im touched unathi amp
# 986                                         nannannan re
# 2617   group  philippine social problems on corruptio...
# 2787   whiteheavycheckmark international nutrition ol...
# 3740   web development full course khris digital acad...
# 3781   nannannannanwatchrefsearchvexternallogidbcaaea...
# 7060   mundo bita  meu pequeno corao by mundo bita  y...
# 13658  mundo bita  meu pequeno corao by mundo bita  y...
#
#                                                Text_chat  \
# 1413   apply better together challenge for young chan...
# 1419   better together challenge for young changemake...
# 3183                         kwaza im touched unathi amp
# 986                                         nannannan re
# 2617   group philippine social problems on corruption...
# 2787   whiteheavycheckmark international nutrition ol...
# 3740   web development full course khris digital acad...
# 3781   nannannannanwatchrefsearchvexternallogidbcaaea...
# 7060   mundo bita meu pequeno corao by mundo bita yea...
# 13658  mundo bita meu pequeno corao by mundo bita yea...
#
#                                               Text_spell  \
# 1413   apply better together challenge for young chan...
# 1419   better together challenge for young changemake...
# 3183                         kwaza im touched unathi amp
# 986                                         nannannan re
# 2617   group philippine social problems on corruption...
# 2787   whiteheavycheckmark international nutrition ol...
# 3740   web development full course khris digital acad...
# 3781   nannannannanwatchrefsearchvexternallogidbcaaea...
# 7060   mundo bita meu pequeno corao by mundo bita yea...
# 13658  mundo bita meu pequeno corao by mundo bita yea...
#
#                                          Text_translate2 Text_langue3
# 1413   apply better together challenge for young chan...           en
# 1419   better together challenge for young changemake...           en
# 3183                         came im touched with us amp           en
# 986                                            this time           en
# 2617   group philippine social problems on corruption...           en
# 2787   whiteheavycheckmark international nutrition ol...           en
# 3740   web development full course khris digital acad...           en
# 3781   nannannannanwatchrefsearchvexternallogidbcaaea...           en
# 7060   mundo bita meu pequeno corao by mundo bita yea...           en
# 13658  mundo bita meu pequeno corao by mundo bita yea...           en

# %%
train_en3.dropna()
# Out:
#       textid                       Date Views sourcetype  \
# 0          1  2019-12-19 15:30:09+00:00     0    twitter
# 1          2  2019-12-05 15:58:40+00:00    54    twitter
# 2          3  2019-12-01 14:36:11+00:00    10    twitter
# 3          4  2019-11-25 07:49:35+00:00     0    twitter
# 4          5  2019-11-21 22:00:30+00:00     4    twitter
# ...      ...                        ...   ...        ...
# 16684  25978                 2017-08-24   390    youtube
# 16829  26092                 2020-08-24   228    youtube
# 16875  26122                 2023-08-22   883    youtube
# 16945  26177                 2016-08-24   692    youtube
# 17425  26538                       None    80    youtube
#
#                                                  alltext  \
# 0      CLIMATE SMART WATER GOVERNANCE SHARED ECOSYSTE...
# 1      READ: #OUTA says that; while universal health ...
# 2      policital and social issues.  You wanna worry ...
# 3      @WalesRugby South Africa has MANY social ills....
# 4      Opposition weaknesses are relevant to the bigg...
# ...                                                  ...
# 16684    Mundo Bita - Meu Pequeno Coração by Mundo Bi...
# 16829    Diversidad social y conflictos en procesos d...
# 16875    Ansou Damaro: les pays gouvernés par les sol...
# 16945    Africanistan : l’Afrique en crise va-t-elle ...
# 17425    Signal de Walf Tv coupé: Bougane apporte son...
#
#                                                 Text_emt  \
# 0      CLIMATE SMART WATER GOVERNANCE SHARED ECOSYSTE...
# 1      REASadness #OUTA says that; while universal he...
# 2      policital and social issues.  You wanna worry ...
# 3      @WalesRugby South Africa has MANY social ills....
# 4      Opposition weaknesses are relevant to the bigg...
# ...                                                  ...
# 16684    Mundo Bita - Meu Pequeno Coração by Mundo Bi...
# 16829    Diversidad social y conflictos en procesos d...
# 16875    Ansou Damaro: les pays gouvernés par les sol...
# 16945    Africanistan : l’Afrique en crise va-t-elle ...
# 17425    Signal de Walf Tv coupé: Bougane apporte son...
#
#                                                 Text_emj Text_langue  \
# 0      CLIMATE SMART WATER GOVERNANCE SHARED ECOSYSTE...          en
# 1      REASadness #OUTA says that; while universal he...          en
# 2      policital and social issues.  You wanna worry ...          en
# 3      @WalesRugby South Africa has MANY social ills....          en
# 4      Opposition weaknesses are relevant to the bigg...          en
# ...                                                  ...         ...
# 16684    Mundo Bita - Meu Pequeno Coração by Mundo Bi...          pt
# 16829    Diversidad social y conflictos en procesos d...          es
# 16875    Ansou Damaro: les pays gouvernés par les sol...          fr
# 16945    Africanistan : l’Afrique en crise va-t-elle ...          fr
# 17425    Signal de Walf Tv coupé: Bougane apporte son...          fr
#
#                                           Text_translate Text_langue2  \
# 0      CLIMATE SMART WATER GOVERNANCE SHARED ECOSYSTE...           en
# 1      REASadness #OUTA says that; while universal he...           en
# 2      policital and social issues.  You wanna worry ...           en
# 3      @WalesRugby South Africa has MANY social ills....           en
# 4      Opposition weaknesses are relevant to the bigg...           en
# ...                                                  ...          ...
# 16684  Mundo Bita - Meu Pequeno Coração by Mundo Bita...           en
# 16829  Social diversity and conflicts in urban transf...           en
# 16875  Ansou Damaro: countries ruled by soldiers have...           en
# 16945  Africanistan: will Africa in crisis end up in ...           en
# 17425  Walf Tv signal cut: Bougane supports Walf and ...           en
#
#                                               Text_lower  \
# 0      climate smart water governance shared ecosyste...
# 1      reasadness #outa says that; while universal he...
# 2      policital and social issues.  you wanna worry ...
# 3      @walesrugby south africa has many social ills....
# 4      opposition weaknesses are relevant to the bigg...
# ...                                                  ...
# 16684  mundo bita - meu pequeno coração by mundo bita...
# 16829  social diversity and conflicts in urban transf...
# 16875  ansou damaro: countries ruled by soldiers have...
# 16945  africanistan: will africa in crisis end up in ...
# 17425  walf tv signal cut: bougane supports walf and ...
#
#                                               Text_punct  \
# 0      climate smart water governance shared ecosyste...
# 1      reasadness  says that while universal health c...
# 2      policital and social issues  you wanna worry f...
# 3      south africa has many social illsxd drugs and ...
# 4      opposition weaknesses are relevant to the bigg...
# ...                                                  ...
# 16684  mundo bita  meu pequeno corao by mundo bita  y...
# 16829  social diversity and conflicts in urban transf...
# 16875  ansou damaro countries ruled by soldiers have ...
# 16945  africanistan will africa in crisis end up in o...
# 17425  walf tv signal cut bougane supports walf and a...
#
#                                                Text_tags  \
# 0      climate smart water governance shared ecosyste...
# 1      reasadness  says that while universal health c...
# 2      policital and social issues  you wanna worry f...
# 3      south africa has many social illsxd drugs and ...
# 4      opposition weaknesses are relevant to the bigg...
# ...                                                  ...
# 16684  mundo bita  meu pequeno corao by mundo bita  y...
# 16829  social diversity and conflicts in urban transf...
# 16875  ansou damaro countries ruled by soldiers have ...
# 16945  africanistan will africa in crisis end up in o...
# 17425  walf tv signal cut bougane supports walf and a...
#
#                                                Text_chat  \
# 0      climate smart water governance shared ecosyste...
# 1      reasadness says that while universal health co...
# 2      policital and social issues you wanna worry fo...
# 3      south africa has many social illsxd drugs and ...
# 4      opposition weaknesses are relevant to the bigg...
# ...                                                  ...
# 16684  mundo bita meu pequeno corao by mundo bita yea...
# 16829  social diversity and conflicts in urban transf...
# 16875  ansou damaro countries ruled by soldiers have ...
# 16945  africanistan will africa in crisis end up in o...
# 17425  walf tv signal cut bougane supports walf and a...
#
#                                               Text_spell
# 0      climate smart water governance shared ecosyste...
# 1      reasadness says that while universal health co...
# 2      policital and social issues you wanna worry fo...
# 3      south africa has many social illsxd drugs and ...
# 4      opposition weaknesses are relevant to the bigg...
# ...                                                  ...
# 16684  mundo bita meu pequeno corao by mundo bita yea...
# 16829  social diversity and conflicts in urban transf...
# 16875  ansou damaro countries ruled by soldiers have ...
# 16945  africanistan will africa in crisis end up in o...
# 17425  walf tv signal cut bougane supports walf and a...
#
# [27535 rows x 15 columns]

# %%
train_en32.head(2)
# Out:
#      textid                       Date Views sourcetype  \
# 1413   1398  2019-07-23 11:01:13+00:00     0    twitter
# 1419   1404  2019-07-19 12:39:18+00:00    15    twitter
#
#                                                 alltext  \
# 1413  APPLY: Better Together Challenge 2019 for youn...
# 1419  Better Together Challenge 2019 for young Chang...
#
#                                                Text_emt  \
# 1413  APPLY: Better Together Challenge 2019 for youn...
# 1419  Better Together Challenge 2019 for young Chang...
#
#                                                Text_emj Text_langue  \
# 1413  APPLY: Better Together Challenge 2019 for youn...          no
# 1419  Better Together Challenge 2019 for young Chang...          no
#
#                                          Text_translate Text_langue2  \
# 1413  APPLY: Better Together Challenge 2019 for youn...           no
# 1419  Better Together Challenge 2019 for young Chang...           no
#
#                                              Text_lower  \
# 1413  apply: better together challenge 2019 for youn...
# 1419  better together challenge 2019 for young chang...
#
#                                              Text_punct  \
# 1413  apply better together challenge  for young cha...
# 1419  better together challenge  for young changemak...
#
#                                               Text_tags  \
# 1413  apply better together challenge  for young cha...
# 1419  better together challenge  for young changemak...
#
#                                               Text_chat  \
# 1413  apply better together challenge for young chan...
# 1419  better together challenge for young changemake...
#
#                                              Text_spell  \
# 1413  apply better together challenge for young chan...
# 1419  better together challenge for young changemake...
#
#                                         Text_translate2 Text_langue3
# 1413  apply better together challenge for young chan...           en
# 1419  better together challenge for young changemake...           en

# %%
train_en3.head(2)
# Out:
#   textid                       Date Views sourcetype  \
# 0      1  2019-12-19 15:30:09+00:00     0    twitter
# 1      2  2019-12-05 15:58:40+00:00    54    twitter
#
#                                              alltext  \
# 0  CLIMATE SMART WATER GOVERNANCE SHARED ECOSYSTE...
# 1  READ: #OUTA says that; while universal health ...
#
#                                             Text_emt  \
# 0  CLIMATE SMART WATER GOVERNANCE SHARED ECOSYSTE...
# 1  REASadness #OUTA says that; while universal he...
#
#                                             Text_emj Text_langue  \
# 0  CLIMATE SMART WATER GOVERNANCE SHARED ECOSYSTE...          en
# 1  REASadness #OUTA says that; while universal he...          en
#
#                                       Text_translate Text_langue2  \
# 0  CLIMATE SMART WATER GOVERNANCE SHARED ECOSYSTE...           en
# 1  REASadness #OUTA says that; while universal he...           en
#
#                                           Text_lower  \
# 0  climate smart water governance shared ecosyste...
# 1  reasadness #outa says that; while universal he...
#
#                                           Text_punct  \
# 0  climate smart water governance shared ecosyste...
# 1  reasadness  says that while universal health c...
#
#                                            Text_tags  \
# 0  climate smart water governance shared ecosyste...
# 1  reasadness  says that while universal health c...
#
#                                            Text_chat  \
# 0  climate smart water governance shared ecosyste...
# 1  reasadness says that while universal health co...
#
#                                           Text_spell
# 0  climate smart water governance shared ecosyste...
# 1  reasadness says that while universal health co...

# %%
# train_not_en.isna().head()
train_en3['Text_langue3']= train_en3['Text_langue2']
# Out:
# <ipython-input-197-3d2ea0280153>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_en3['Text_langue3']= train_en3['Text_langue2']

# %%
train_en3['Text_translate2']= train_en3['Text_spell']
# Out:
# <ipython-input-198-08967c5e6727>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_en3['Text_translate2']= train_en3['Text_spell']

# %%
shuffledlw = train_not_en32.sample(frac=1)
shuffledlw.head(10)
# Out:
#      textid                       Date Views sourcetype  \
# 3874  11749                       None   128   facebook
# 7605   7428  2022-06-30 13:35:09+00:00     6    twitter
# 1164   9917                       None    15   facebook
# 342    9244                       None     0   facebook
# 766    9632                       None     0   facebook
# 2413   2371  2020-10-28 13:30:10+00:00     2    twitter
# 4359  12158                       None     0   facebook
# 1336  10053                       None   499   facebook
# 3617  11632                       None   369   facebook
# 582     577  2019-08-08 08:58:27+00:00     8    twitter
#
#                                                 alltext  \
# 3874   nannannannanP   r   i   n   c   Y   o   r   k...
# 7605                                      Social &amp
# 1164   nannannannanSarala RajendranApr 4, 2022 · 15 ...
# 342                              nannannannan Botswan"
# 766    nannannannan/gregg.fick/videos/33966311503658...
# 2413                                         Live &gt
# 4359   nannannannan/texan.buddha/videos/334083218263...
# 1336   nannannannanPhindile George ZibulaMar 4, 2022...
# 3617   nannannannanWork Permit Visa Agent & Visa Con...
# 582
#
#                                                Text_emt  \
# 3874   nannannannanP   r   i   n   c   Y   o   r   k...
# 7605                                      Social &amp
# 1164   nannannannanSarala RajendranApr 4, 2022 · 15 ...
# 342                              nannannannan Botswan"
# 766    nannannannan/gregg.fick/videos/33966311503658...
# 2413                                         Live &gt
# 4359   nannannannan/texan.buddha/videos/334083218263...
# 1336   nannannannanPhindile George ZibulaMar 4, 2022...
# 3617   nannannannanWork Permit Visa Agent & Visa Con...
# 582
#
#                                                Text_emj Text_langue  \
# 3874   nannannannanP   r   i   n   c   Y   o   r   k...          cy
# 7605                                      Social &amp            ca
# 1164   nannannannanSarala RajendranApr 4, 2022 · 15 ...          sv
# 342                              nannannannan Botswan"           tl
# 766    nannannannan/gregg.fick/videos/33966311503658...          sv
# 2413                                         Live &gt            da
# 4359   nannannannan/texan.buddha/videos/334083218263...          sv
# 1336   nannannannanPhindile George ZibulaMar 4, 2022...          de
# 3617   nannannannanWork Permit Visa Agent & Visa Con...          fi
# 582                                                         unknown
#
#                                          Text_translate Text_langue2  \
# 3874  nannannannanP   r   i   n   c   Y   o   r   kJ...           cy
# 7605                                      Social &amp             ca
# 1164    nannannanSarala RajendranApr 4, 2022 · 15 views           sv
# 342                               nannannannan Botswan"           tl
# 766    nannannannan/gregg.fick/videos/3396631150365848/           sv
# 2413                                           Live &gt           da
# 4359   nannannannan/texan.buddha/videos/334083218263...           sv
# 1336  nannannanPhindile George ZibulaMar 4, 2022 · 4...           de
# 3617  nannannannanWork Permit Visa Agent & Visa Cons...           fi
# 582                                                          unknown
#
#                                              Text_lower  \
# 3874  nannannannanp   r   i   n   c   y   o   r   kj...
# 7605                                      social &amp
# 1164    nannannansarala rajendranapr 4, 2022 · 15 views
# 342                               nannannannan botswan"
# 766    nannannannan/gregg.fick/videos/3396631150365848/
# 2413                                           live &gt
# 4359   nannannannan/texan.buddha/videos/334083218263...
# 1336  nannannanphindile george zibulamar 4, 2022 · 4...
# 3617  nannannannanwork permit visa agent & visa cons...
# 582
#
#                                              Text_punct  \
# 3874  nannannannanp   r   i   n   c   y   o   r   kj...
# 7605                                         social amp
# 1164             nannannansarala rajendranapr     views
# 342                                nannannannan botswan
# 766                         nannannannangreggfickvideos
# 2413                                            live gt
# 4359                      nannannannantexanbuddhavideos
# 1336       nannannanphindile george zibulamar     views
# 3617  nannannannanwork permit visa agent  visa consu...
# 582
#
#                                               Text_tags  \
# 3874  nannannannanp   r   i   n   c   y   o   r   kj...
# 7605                                         social amp
# 1164             nannannansarala rajendranapr     views
# 342                                nannannannan botswan
# 766                         nannannannangreggfickvideos
# 2413                                            live gt
# 4359                      nannannannantexanbuddhavideos
# 1336       nannannanphindile george zibulamar     views
# 3617  nannannannanwork permit visa agent  visa consu...
# 582
#
#                                               Text_chat  \
# 3874             nannannannanp r i n c y o r kjun views
# 7605                                         social amp
# 1164                 nannannansarala rajendranapr views
# 342                                nannannannan botswan
# 766                         nannannannangreggfickvideos
# 2413                                            live gt
# 4359                      nannannannantexanbuddhavideos
# 1336           nannannanphindile george zibulamar views
# 3617  nannannannanwork permit visa agent visa consul...
# 582
#
#                                              Text_spell  \
# 3874             nannannannanp r i n c y o r kjun views
# 7605                                         social amp
# 1164                 nannannansarala rajendranapr views
# 342                                nannannannan botswan
# 766                         nannannannangreggfickvideos
# 2413                                            live gt
# 4359                      nannannannantexanbuddhavideos
# 1336           nannannanphindile george zibulamar views
# 3617  nannannannanwork permit visa agent visa consul...
# 582                                                   i
#
#                                         Text_translate2 Text_langue3
# 3874             nannannannanp r i n c y o r kjun views           cy
# 7605                                         social amp           ca
# 1164                  nannannansarala rajendranap views           id
# 342                                nannannannan botswan           tl
# 766                         nannannannangreggfickvideos           sv
# 2413                                            live gt           da
# 4359                      nannannannantexanbuddhavideos           sv
# 1336           nannannanphindile george zibulamar views           nl
# 3617  nannannannanwork permit visa agent visa consul...           fi
# 582                                                   i           af

# %%
df2 = pd.concat([train_en3, train_en32])

# %%
df2.shape
# Out:
# (27545, 17)

# %%
df2.head(2)
# Out:
#   textid                       Date Views sourcetype  \
# 0      1  2019-12-19 15:30:09+00:00     0    twitter
# 1      2  2019-12-05 15:58:40+00:00    54    twitter
#
#                                              alltext  \
# 0  CLIMATE SMART WATER GOVERNANCE SHARED ECOSYSTE...
# 1  READ: #OUTA says that; while universal health ...
#
#                                             Text_emt  \
# 0  CLIMATE SMART WATER GOVERNANCE SHARED ECOSYSTE...
# 1  REASadness #OUTA says that; while universal he...
#
#                                             Text_emj Text_langue  \
# 0  CLIMATE SMART WATER GOVERNANCE SHARED ECOSYSTE...          en
# 1  REASadness #OUTA says that; while universal he...          en
#
#                                       Text_translate Text_langue2  \
# 0  CLIMATE SMART WATER GOVERNANCE SHARED ECOSYSTE...           en
# 1  REASadness #OUTA says that; while universal he...           en
#
#                                           Text_lower  \
# 0  climate smart water governance shared ecosyste...
# 1  reasadness #outa says that; while universal he...
#
#                                           Text_punct  \
# 0  climate smart water governance shared ecosyste...
# 1  reasadness  says that while universal health c...
#
#                                            Text_tags  \
# 0  climate smart water governance shared ecosyste...
# 1  reasadness  says that while universal health c...
#
#                                            Text_chat  \
# 0  climate smart water governance shared ecosyste...
# 1  reasadness says that while universal health co...
#
#                                           Text_spell Text_langue3  \
# 0  climate smart water governance shared ecosyste...           en
# 1  reasadness says that while universal health co...           en
#
#                                      Text_translate2
# 0  climate smart water governance shared ecosyste...
# 1  reasadness says that while universal health co...

# %%
df_new21=df2['Text_langue3'].value_counts().reset_index()#.plot(kind='bar')
ax = sns.barplot(x='Text_langue3', y='index', data=df_new21)
ax.set_title('Count of records for all languages in data')
ax.set_xlabel('Languages in data')
ax.set_ylabel('Number of count')
plt.show()

# %%
df=df2.copy()
df=df.astype(str)
df.head()
# Out:
#   textid                       Date Views sourcetype  \
# 0      1  2019-12-19 15:30:09+00:00     0    twitter
# 1      2  2019-12-05 15:58:40+00:00    54    twitter
# 2      3  2019-12-01 14:36:11+00:00    10    twitter
# 3      4  2019-11-25 07:49:35+00:00     0    twitter
# 4      5  2019-11-21 22:00:30+00:00     4    twitter
#
#                                              alltext  \
# 0  CLIMATE SMART WATER GOVERNANCE SHARED ECOSYSTE...
# 1  READ: #OUTA says that; while universal health ...
# 2  policital and social issues.  You wanna worry ...
# 3  @WalesRugby South Africa has MANY social ills....
# 4  Opposition weaknesses are relevant to the bigg...
#
#                                             Text_emt  \
# 0  CLIMATE SMART WATER GOVERNANCE SHARED ECOSYSTE...
# 1  REASadness #OUTA says that; while universal he...
# 2  policital and social issues.  You wanna worry ...
# 3  @WalesRugby South Africa has MANY social ills....
# 4  Opposition weaknesses are relevant to the bigg...
#
#                                             Text_emj Text_langue  \
# 0  CLIMATE SMART WATER GOVERNANCE SHARED ECOSYSTE...          en
# 1  REASadness #OUTA says that; while universal he...          en
# 2  policital and social issues.  You wanna worry ...          en
# 3  @WalesRugby South Africa has MANY social ills....          en
# 4  Opposition weaknesses are relevant to the bigg...          en
#
#                                       Text_translate Text_langue2  \
# 0  CLIMATE SMART WATER GOVERNANCE SHARED ECOSYSTE...           en
# 1  REASadness #OUTA says that; while universal he...           en
# 2  policital and social issues.  You wanna worry ...           en
# 3  @WalesRugby South Africa has MANY social ills....           en
# 4  Opposition weaknesses are relevant to the bigg...           en
#
#                                           Text_lower  \
# 0  climate smart water governance shared ecosyste...
# 1  reasadness #outa says that; while universal he...
# 2  policital and social issues.  you wanna worry ...
# 3  @walesrugby south africa has many social ills....
# 4  opposition weaknesses are relevant to the bigg...
#
#                                           Text_punct  \
# 0  climate smart water governance shared ecosyste...
# 1  reasadness  says that while universal health c...
# 2  policital and social issues  you wanna worry f...
# 3  south africa has many social illsxd drugs and ...
# 4  opposition weaknesses are relevant to the bigg...
#
#                                            Text_tags  \
# 0  climate smart water governance shared ecosyste...
# 1  reasadness  says that while universal health c...
# 2  policital and social issues  you wanna worry f...
# 3  south africa has many social illsxd drugs and ...
# 4  opposition weaknesses are relevant to the bigg...
#
#                                            Text_chat  \
# 0  climate smart water governance shared ecosyste...
# 1  reasadness says that while universal health co...
# 2  policital and social issues you wanna worry fo...
# 3  south africa has many social illsxd drugs and ...
# 4  opposition weaknesses are relevant to the bigg...
#
#                                           Text_spell Text_langue3  \
# 0  climate smart water governance shared ecosyste...           en
# 1  reasadness says that while universal health co...           en
# 2  policital and social issues you wanna worry fo...           en
# 3  south africa has many social illsxd drugs and ...           en
# 4  opposition weaknesses are relevant to the bigg...           en
#
#                                      Text_translate2
# 0  climate smart water governance shared ecosyste...
# 1  reasadness says that while universal health co...
# 2  policital and social issues you wanna worry fo...
# 3  south africa has many social illsxd drugs and ...
# 4  opposition weaknesses are relevant to the bigg...

# %% [markdown]
# ### Annotation of data

# %%
# Will be extracted using Sentiment analysis

# %%
# Tokenizing or splitting a string, text into a list of tokens
import nltk

from nltk.tokenize import word_tokenize
def tokenizingText(text):
    text = word_tokenize(text)
    return text
df['Text_token'] = df['Text_spell'].astype(str)
df['Text_token'] = df['Text_spell'].apply(tokenizingText)
df['Text_token'].head()
# Out:
# 0    [climate, smart, water, governance, shared, ec...
# 1    [reasadness, says, that, while, universal, hea...
# 2    [policital, and, social, issues, you, wan, na,...
# 3    [south, africa, has, many, social, illsxd, dru...
# 4    [opposition, weaknesses, are, relevant, to, th...
# Name: Text_token, dtype: object

# %%
# Remove stopwors in a text
import nltk
nltk.download('stopwords')
nltk.download('punkt')
from nltk.corpus import stopwords
STOPWORDS = set(stopwords.words('english'))
# Function to remove the stopwords
def stopwords(text):
    return " ".join([word for word in str(text).split() if word not in STOPWORDS])
df['Text_stop'] = df['Text_spell'].astype(str)
df['Text_stop'] = df['Text_spell'].apply(stopwords)
df['Text_stop'].head()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 0    climate smart water governance shared ecosyste...
# 1    reasadness says universal health coverage soci...
# 2    policital social issues wanna worry people lot...
# 3    south africa many social illsxd drugs schools ...
# 4    opposition weaknesses relevant bigger concern ...
# Name: Text_stop, dtype: object

# %%
df.columns
# Out:
# Index(['textid', 'Date', 'Views', 'sourcetype', 'alltext', 'Text_emt',
#        'Text_emj', 'Text_langue', 'Text_translate', 'Text_langue2',
#        'Text_lower', 'Text_punct', 'Text_tags', 'Text_chat', 'Text_spell',
#        'Text_langue3', 'Text_translate2', 'Text_token', 'Text_stop'],
#       dtype='object')

# %%
shuffledlw=df[['textid', 'alltext', 'sourcetype','Text_spell', 'Text_token','Text_stop']]
shuffledlw = shuffledlw.sample(frac=1)
shuffledlw.head(10)
# Out:
#       textid                                            alltext sourcetype  \
# 16232  25625    Jackson Kaguri: 2015 Social Good Summit by U...    youtube
# 8990   19813    Current Affairs 2022 in English | Last 6 Mon...    youtube
# 8689   19583    Strengthening Public Health Operations Centr...    youtube
# 6464    6317  @JayNtuli_SA @OfficialPSL ðŸ˜‚ðŸ˜‚ðŸ˜‚No I wan...    twitter
# 1265    9993   The Spectrum of Monetary Sovereignty in Devel...   facebook
# 1127   13515    Being the Queen: The Life of Queen Elizabeth...    youtube
# 507      504  Blockchain Use Case: Addressing Corruption; So...    twitter
# 2972   14999    How to Reset Forgot PayPal Password by Max D...    youtube
# 7028    6852  AFRICA/BENIN - Insecurity and climate change e...    twitter
# 18346  27165    Shakira - Hips Don't Lie (Live) ft. Wyclef J...    youtube
#
#                                               Text_spell  \
# 16232  jackson kaguri social good summit by united na...
# 8990   current affairs in english last months most im...
# 8689   strengthening public health operations centres...
# 6464   sa no i want them to hire lot of people to pro...
# 1265   the spectrum of monetary sovereignty in develo...
# 1127   being the queen the life of queen elizabeth ii...
# 507    blockchain use case addressing corruption soci...
# 2972   how to reset forgot paypal password by max dal...
# 7028   africabenin insecurity and climate change enda...
# 18346  shakira hips dont lie liveconfusion ft wyclef ...
#
#                                               Text_token  \
# 16232  [jackson, kaguri, social, good, summit, by, un...
# 8990   [current, affairs, in, english, last, months, ...
# 8689   [strengthening, public, health, operations, ce...
# 6464   [sa, no, i, want, them, to, hire, lot, of, peo...
# 1265   [the, spectrum, of, monetary, sovereignty, in,...
# 1127   [being, the, queen, the, life, of, queen, eliz...
# 507    [blockchain, use, case, addressing, corruption...
# 2972   [how, to, reset, forgot, paypal, password, by,...
# 7028   [africabenin, insecurity, and, climate, change...
# 18346  [shakira, hips, dont, lie, liveconfusion, ft, ...
#
#                                                Text_stop
# 16232  jackson kaguri social good summit united natio...
# 8990   current affairs english last months important ...
# 8689   strengthening public health operations centres...
# 6464   sa want hire lot people promote dstv disk chal...
# 1265   spectrum monetary sovereignty developing natio...
# 1127   queen life queen elizabeth ii national geograp...
# 507    blockchain use case addressing corruption soci...
# 2972   reset forgot paypal password max dalton year a...
# 7028   africabenin insecurity climate change endanger...
# 18346  shakira hips dont lie liveconfusion ft wyclef ...

# %%
#df.to_excel("C:/Users/Administrator/OneDrive/Documents/africa/dataafrica/socialconcernsnew.xlsx", index=False)

# %% [markdown]
# Lemmatization vs stemming
#
# * Stemming is a faster process than lemmatization as stemming chops off the word irrespective of the context, whereas the latter is context-dependent
# * Stemming is a rule-based approach, whereas lemmatization is a canonical dictionary-based approach.
# * Lemmatization has higher accuracy than stemming.
# * Lemmatization is preferred for context analysis, whereas stemming is recommended when the context is not important.

# %% [markdown]
# We explore the most common stemmers available in the NLTK library
#
# * Porter's Stemmer is the oldest stemmer method. Porter's Stemmer applies a set of five sequential rule to determine common suffixes from sentences done with regular expressions
# * Snowball stemmer is an updated version of Porter’s Stemmer with new rules. The process is exactly the same as Porter’s Stemmer
# * Lancaster Stemmer rules are more agressive than Porter and Snowball and it is one of the most agressive stemmers. As a general rule of thumb, think that the rules of Lancaster’s Stemmer try to reduce the word to the shortest stem possible

# %%
# text = "hello I was thinking about your point of view africa ecommerce must be social and a challenge that quickly appears is where to place yourself on the scale of access to customer servicexd xd the extremes cf imageconfusion are ineffectivexd xd looking forward to hear you"

# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem import SnowballStemmer, LancasterStemmer,  PorterStemmer,WordNetLemmatizer
from nltk.corpus import wordnet
nltk.download('averaged_perceptron_tagger')
nltk.download('punkt')
nltk.download('omw-1.4')

import warnings
warnings.filterwarnings('ignore')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...

# %%
porter = PorterStemmer()
porter.stem('going')
# Out:
# 'go'

# %%
tokenized_eu = word_tokenize(text)
porter_eu = [porter.stem(word) for word in tokenized_eu]
print(f" PorterStemmer: {100*round(len(''.join(porter_eu))/len(''.join(word_tokenize(text))),3)}%")

snowball = SnowballStemmer(language='english')
porter_eu = [snowball.stem(word) for word in tokenized_eu]
print(f" SnowballStemmer: {100*round(len(''.join(porter_eu))/len(''.join(word_tokenize(text))),3)}%")

lanc = LancasterStemmer()
porter_eu = [lanc.stem(word) for word in tokenized_eu]
print(f" LancasterStemmerr: {100*round(len(''.join(porter_eu))/len(''.join(word_tokenize(text))),3)}%")
# Out:
#  PorterStemmer: 84.8%
#  SnowballStemmer: 84.8%
#  LancasterStemmerr: 81.8%

# %%
# Reducing a word to its word stem that affixes to suffixes and prefixes or to the roots of words
import string
from nltk.stem.porter import PorterStemmer

stemmer = PorterStemmer()
def stem_words(text):
    return " ".join([stemmer.stem(word) for word in text.split()])

df['Text_stem'] = df['Text_stop'].astype(str)
df['Text_stem'] = df['Text_stop'].apply(stem_words)
df['Text_stem'].head()
# Out:
# 0    climat smart water govern share ecosystemxd in...
# 1    reasad say univers health coverag social moral...
# 2    policit social issu wanna worri peopl lot dese...
# 3    south africa mani social illsxd drug school ma...
# 4    opposit weak relev bigger concern anc governme...
# Name: Text_stem, dtype: object

# %% [markdown]
# Lemmatization
#
# * Lemmatization is similar to stemming in reducing inflected words to their word stem but differs in the way that it makes sure the root word (also called as lemma) belongs to the language.
#
# * As a result, this one is generally slower than stemming process. So depending on the speed requirement, we can choose to use either stemming or lemmatization.
#
# * Let us use the WordNetLemmatizer in nltk to lemmatize our sentences

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
def lemmatize_words(text):
    return " ".join([lemmatizer.lemmatize(word) for word in text.split()])

df["Text_lemma"] = df["Text_stop"].astype(str)
df["Text_lemma"] = df["Text_stop"].apply(lambda text: lemmatize_words(text))
df["Text_lemma"].head()
# Out:
# 0    climate smart water governance shared ecosyste...
# 1    reasadness say universal health coverage socia...
# 2    policital social issue wanna worry people lot ...
# 3    south africa many social illsxd drug school ma...
# 4    opposition weakness relevant bigger concern an...
# Name: Text_lemma, dtype: object

# %%
shuffledlw=df[['textid', 'alltext', 'sourcetype','Text_stop','Text_stem','Text_lemma']]
shuffledlw = shuffledlw.sample(frac=1)
shuffledlw.head(10)
# Out:
#       textid                                            alltext sourcetype  \
# 11203  21534    Inmate kills cellmate and hides body without...    youtube
# 15362  24868    was it a SET UP? : Rapper AKA's last post ra...    youtube
# 8785    8583  Gee; why should we worry about someone whose f...    twitter
# 1834    1812  We can't wait to hear @Cc_HUB's plans for the ...    twitter
# 1199    1190  Social inclusion is central to #Africaâ€™s ach...    twitter
# 4652    4554  @dustynotjusty Am based in South Africa a very...    twitter
# 249     9151   REMINDER : The Robin Hood Foundation South Af...   facebook
# 1127   13515    Being the Queen: The Life of Queen Elizabeth...    youtube
# 1282   13634    20 Most Developed Countries in Africa 2020 b...    youtube
# 802      797  Our Man Crush Monday is @bosuntijani founder a...    twitter
#
#                                                Text_stop  \
# 11203  inmate kills cellmate hides body without guard...
# 15362  set rapper akas last post raises questions dur...
# 8785   gee worry someone whose father moved family so...
# 1834   cant wait hear hubs plans launch amp global so...
# 1199   social inclusion central trademarks achievemen...
# 4652   based south africa staunch garyvian question w...
# 249    reminder robin hood foundation south africa ch...
# 1127   queen life queen elizabeth ii national geograp...
# 1282   developed countries africa displore years ago ...
# 802    man crush monday founder ceo hub platform tech...
#
#                                                Text_stem  \
# 11203  inmat kill cellmat hide bodi without guard not...
# 15362  set rapper aka last post rais question durban ...
# 8785   gee worri someon whose father move famili sout...
# 1834   cant wait hear hub plan launch amp global soci...
# 1199   social inclus central trademark achiev tackl c...
# 4652   base south africa staunch garyvian question wa...
# 249    remind robin hood foundat south africa challen...
# 1127   queen life queen elizabeth ii nation geograph ...
# 1282   develop countri africa displor year ago minut ...
# 802    man crush monday founder ceo hub platform tech...
#
#                                               Text_lemma
# 11203  inmate kill cellmate hide body without guard n...
# 15362  set rapper akas last post raise question durba...
# 8785   gee worry someone whose father moved family so...
# 1834   cant wait hear hub plan launch amp global soci...
# 1199   social inclusion central trademark achievement...
# 4652   based south africa staunch garyvian question w...
# 249    reminder robin hood foundation south africa ch...
# 1127   queen life queen elizabeth ii national geograp...
# 1282   developed country africa displore year ago min...
# 802    man crush monday founder ceo hub platform tech...

# %%
#df = pd.read_excel('C:/Users/Administrator/OneDrive/Documents/africa/dataafrica/socialconcernsnew3.xlsx',sheet_name='Sheet1')

# %%
# df.head(2)

# %%
#df = df.dropna()
#df = df.reset_index(drop=True)
print("No. of columns containing null values")
print(len(df.columns[df.isna().any()]))

print("No. of columns not containing null values")
print(len(df.columns[df.notna().all()]))

print("Total no. of columns in the dataframe")
print(len(df.columns))
# Out:
# No. of columns containing null values
# 0
# No. of columns not containing null values
# 21
# Total no. of columns in the dataframe
# 21

# %%
df.shape
# Out:
# (27545, 21)

# %%
# df = df.drop(df.columns[df.isna().sum()>len(df.columns)],axis = 1)
# df = df.dropna(axis = 0).reset_index(drop=True)

df = df[~df.isin(['nan']).any(axis=1)]
df.head(2)
# Out:
#   textid                       Date Views sourcetype  \
# 0      1  2019-12-19 15:30:09+00:00     0    twitter
# 1      2  2019-12-05 15:58:40+00:00    54    twitter
#
#                                              alltext  \
# 0  CLIMATE SMART WATER GOVERNANCE SHARED ECOSYSTE...
# 1  READ: #OUTA says that; while universal health ...
#
#                                             Text_emt  \
# 0  CLIMATE SMART WATER GOVERNANCE SHARED ECOSYSTE...
# 1  REASadness #OUTA says that; while universal he...
#
#                                             Text_emj Text_langue  \
# 0  CLIMATE SMART WATER GOVERNANCE SHARED ECOSYSTE...          en
# 1  REASadness #OUTA says that; while universal he...          en
#
#                                       Text_translate Text_langue2  ...  \
# 0  CLIMATE SMART WATER GOVERNANCE SHARED ECOSYSTE...           en  ...
# 1  REASadness #OUTA says that; while universal he...           en  ...
#
#                                           Text_punct  \
# 0  climate smart water governance shared ecosyste...
# 1  reasadness  says that while universal health c...
#
#                                            Text_tags  \
# 0  climate smart water governance shared ecosyste...
# 1  reasadness  says that while universal health c...
#
#                                            Text_chat  \
# 0  climate smart water governance shared ecosyste...
# 1  reasadness says that while universal health co...
#
#                                           Text_spell Text_langue3  \
# 0  climate smart water governance shared ecosyste...           en
# 1  reasadness says that while universal health co...           en
#
#                                      Text_translate2  \
# 0  climate smart water governance shared ecosyste...
# 1  reasadness says that while universal health co...
#
#                                           Text_token  \
# 0  [climate, smart, water, governance, shared, ec...
# 1  [reasadness, says, that, while, universal, hea...
#
#                                            Text_stop  \
# 0  climate smart water governance shared ecosyste...
# 1  reasadness says universal health coverage soci...
#
#                                            Text_stem  \
# 0  climat smart water govern share ecosystemxd in...
# 1  reasad say univers health coverag social moral...
#
#                                           Text_lemma
# 0  climate smart water governance shared ecosyste...
# 1  reasadness say universal health coverage socia...
#
# [2 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['textid', 'Date', 'Views', 'sourcetype', 'alltext', 'Text_emt',
#        'Text_emj', 'Text_langue', 'Text_translate', 'Text_langue2',
#        'Text_lower', 'Text_punct', 'Text_tags', 'Text_chat', 'Text_spell',
#        'Text_langue3', 'Text_translate2', 'Text_token', 'Text_stop',
#        'Text_stem', 'Text_lemma'],
#       dtype='object')

# %%
df.shape
# Out:
# (27545, 21)

# %%
df2=df.dropna()
df2.shape
# Out:
# (27545, 21)

# %%
# df.to_csv("C:/Users/Administrator/OneDrive/Documents/africa/dataafrica/socialcons_clean2.csv", encoding = "UTF-8")
# df.to_csv("D:/senego/dataafrica/oldfiles/socialcons_clean2.csv", encoding = "UTF-8")
df.to_csv('/content/drive/MyDrive/Colab Notebooks/socialcons_clean2.csv')

# %%
# df.head(2)

# %%
# cleandf = spark.read.csv("D:/senego/dataafrica/oldfiles/socialcons_clean2.csv", header=True, inferSchema=True)
# cleandf.limit(5)

# %%
# cleandf2=cleandf.dropna()

# %%
# cleandf2.printSchema()

# %%
# cleandf2.limit(2)

# %%
# cleandf2.write \
#   .format("jdbc") \
#   .option("driver","com.mysql.cj.jdbc.Driver") \
#   .option("url", "jdbc:mysql://localhost:3306/socialconcernsnew3?serverTimezone=UTC") \
#   .option("dbtable", "social_cons_all2") \
#   .option("user", "root") \
#   .option("password", "Sibitary1#") \
#   .save()
